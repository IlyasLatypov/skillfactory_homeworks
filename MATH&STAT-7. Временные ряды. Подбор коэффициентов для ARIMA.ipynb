# %% [markdown]
# ![f390011532.jpg](attachment:f390011532.jpg)

# %% [markdown]
# ![dc52f47a96.jpg](attachment:dc52f47a96.jpg)

# %% [markdown]
# ![e9b6cb9ca8.jpg](attachment:e9b6cb9ca8.jpg)

# %% [markdown]
# ![8b6f227323.jpg](attachment:8b6f227323.jpg)

# %% [markdown]
# ![221976e677.jpg](attachment:221976e677.jpg)

# %% [markdown]
# ARIMA – модель прогнозирования значений трафика (статья): http://www.isa.ru/jitcs/images/documents/2011-02/41_49.pdf

# %% [markdown]
# ПРОГНОЗИРОВАНИЕ ВРЕМЕННЫХ РЯДОВ С ПОМОЩЬЮ ARIMA В PYTHON 3 (статья): https://www.8host.com/blog/prognozirovanie-vremennyx-ryadov-s-pomoshhyu-arima-v-python-3/

# %% [markdown]
# Анализ временных рядов с помощью python (статья): https://habr.com/ru/post/207160/
