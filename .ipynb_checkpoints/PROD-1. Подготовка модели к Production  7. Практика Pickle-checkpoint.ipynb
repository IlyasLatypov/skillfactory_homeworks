# %% [markdown]
# # ЗАДАНИЕ 1

# %% [markdown]
# Коллега обучил модель и теперь просит вас проверить её на ваших данных. Он присылает вам Pickle-файл. Загрузите модель, используя модуль Pickle.

# %%
import pickle
with open('input/hw1.pkl', 'rb') as pkl_file:
    regressor_from_file = pickle.load(pkl_file)

regressor_from_file
# Out:
# secret word: skillfactory
# how is this possible? answer is here: https://youtu.be/xm-A-h9QkXg
# C:\Users\vandr\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# LinearRegression()

# %%
type(regressor_from_file)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# import numpy as np
X = np.array([1, 1, 1, 0.661212487096872])

X = X.reshape(-1, 1)

# %%
regressor_from_file.predict(X.T) # транспонировал матрицу, потому что в противном случае не захотело работать
# Out:
# array([0.666])

# %% [markdown]
# # ЗАДАНИЕ 2

# %% [markdown]
# У модели есть два поля с именами a и b. Создайте из них словарь с такими же именами ключей и значениями, а затем сохраните в файл с помощью модуля Pickle.
#
# Проверить, что вы всё сделали правильно, можно с помощью скрипта.

# %%
dict = {'a': 1, 'b': 2}

with open('input/myfile_2.pkl', 'wb') as output:
       pickle.dump(dict, output)

# %%
with open('input/myfile_2.pkl', 'rb') as pkl_file:
    regressor_from_file = pickle.load(pkl_file)
    
regressor_from_file
# Out:
# {'a': 1, 'b': 2}

# %%
(lambda __g, __print: [[[[[[(lambda __after: [[(f.close(), [(lambda __after: (__print('wrong answer'), __after())[1] if (((14 * a) + b) != ((14 * asd()) + ____asd())) else [(__print(('secret code 2:', h.hexdigest()[:5])), __after())[1] for __g['h'] in [(hashlib.md5((____asd.__name__ + asd.__name__).encode()))]][0])(lambda: __after()) for (__g['a'], __g['b']) in [((load['a'], load['b']))]][0])[1] for __g['load'] in [(pickle.load(pkl_file))]][0] for __g['f'] in [(open(sys.argv[1], 'rb'))]][0] if (__name__ == '__main__') else __after())(lambda: None) for __g['asd'], asd.__name__ in [(lambda : (____asd() - 8), 'asd')]][0] for __g['____asd'], ____asd.__name__ in [(lambda : ((int(math.pi) * 4) + 1), '____asd')]][0] for __g['hashlib'] in [(__import__('hashlib', __g, __g))]][0] for __g['sys'] in [(__import__('sys', __g, __g))]][0] for __g['pickle'] in [(__import__('pickle', __g, __g))]][0] for __g['math'] in [(__import__('math', __g, __g))]][0])(globals(), __import__('builtins', level=0).__dict__['print'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-69d3dde2578c> in <module>
# ...

# %% [markdown]
# ПОЛЕЗНЫЕ ССЫЛКИ
#
# Документация по работе с Pickle: https://docs.python.org/3/library/pickle.html
#
# Документация по работе с Joblib: https://joblib.readthedocs.io/en/latest/
