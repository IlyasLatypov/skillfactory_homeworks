# %% [markdown]
# Вы уже умеете готовить модели машинного обучения: они выдают на выходе какие-то предсказания, вы научились оценивать их с помощью метрик качества. Вы можете нарисовать какие-то графики и сделать выводы на основе данных. Но что дальше?
#
# Важно задаться следующими вопросами:
#
# Кто будет основными потребителями результатов: другие сервисы? Или модель будет встроена в мобильное приложение?
# Как и в каком виде потребители ожидают получать результаты? По времени или по запросу? И если это так, то по каким правилам они будут осуществлять запрос?
# Какая существует или планируется инфраструктура для этого?
# Определение: деплой
#
# Задача развертывания приложения на сервере называется деплой (от англ. deployment — внедрение, развертывание). По сути это процесс трансформации исходного кода вашего приложения в рабочее состояние на конкретном сервере.
#
# Для того, чтобы внедрить модель в продакшн, необходимо сохранить обученную модель в файл, поднять сервер, а затем доставить и запустить на нём свою модель. Звучит довольно просто, не так ли?

# %% [markdown]
# ВСЁ НЕ ТАК УЖ ПРОСТО
#
# К сожалению, при моделировании зачастую не учитываются вопросы, связанные с деплоем модели и ее внедрением в уже существующие системы.
#
# Для чего мы обучили модель? Может быть, мы будем использовать ее для чат-бота? Может быть, она должна быть встроена в приложение для iPhone? Как часто потребуется переобучать модель?
#
# Опыт подсказывает, что если модель создаётся в вакууме, то на выходе она просто не сможет быть доставлена в продакшн.
#
# Дополнительной проблемой является и тот факт, что большинство библиотек для машинного обучения сфокусированы именно на обучении, а не на предсказании.
#
# К тому же, в крупных компаниях дата-сайентисты, дата-инженеры, ML-инженеры, занимающиеся внедрением моделей в продакшн, могут быть не просто разными людьми, но и разными командами. На практике может оказаться так, что готовая обученная модель будет внедрена другой командой на другом языке программирования. При этом обычным разработчикам модели машинного обучения могут представляться непрозрачными темными ящиками, которые работают, пожалуй, только с помощью черной магии.
#
# Как же учесть все эти сложности в процессе разработки моделей? Давайте разбираться.
