# %% [markdown]
# Представьте ситуацию: вы садитесь за руль автомобиля и… вам нужно заново учиться водить! Сложная ситуация, не правда ли? В реальности мы просто заводим машину, включаем передачу и начинаем движение.
#
# Примерно того же продакшн-среда требует от моделей. И это понятно, ведь намного дешевле хранить данные в виде готовой модели, чем каждый раз заново обучать модель на сервере из восьми видеокарт.
#
# Термин: инференс
#
# Именно поэтому код, который был написан в процессе обучения, крайне редко используется для его инференса (от англ inference — вывод). Так называется непрерывная работа алгоритма машинного обучения в конечном приложении. Именно поэтому при внедрении моделей в продакшн их принято сохранять в готовом виде.

# %% [markdown]
# Изучив материалы в этом блоке, вы сможете:
#
# 1. Подробно разобраться с тем, как с помощью библиотеки Pickle сохранять обученные модели машинного обучения, загружать их обратно и заново обращаться к ним для предсказаний.
#
# 2. Узнать о способах передачи наших моделей для внедрения на языках программирования, отличных от Python.
#
# 3. Разобраться с темой сериализации — процессом трансформации объектов, например обученных моделей, в последовательность битов.
#
# ⭐ Совет. Обязательно попробуйте воспроизвести разбираемые в курсе примеры.
