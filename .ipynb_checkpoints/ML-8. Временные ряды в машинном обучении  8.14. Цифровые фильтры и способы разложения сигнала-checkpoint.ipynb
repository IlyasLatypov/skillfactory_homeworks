# %% [markdown]
# Оконные функции используются для выделения/подавления определённых частот сигнала. Чтобы выделить конкретную частоту из сигнала, нужно сначала знать, какие частоты присутствуют в сигнале. Получить частоты сигнала позволяет преобразование Фурье.
#
# На графике изображен сигнал с шумом и его амплитудно-частотная характеристика (АЧХ):

# %% [markdown]
# ![m8_14_image1.png](attachment:m8_14_image1.png)

# %% [markdown]
# Преобразование Фурье
#
# Один из способов разложения сигнала. Преобразование Фурье представляет сигнал в виде комбинации синусов и косинусов разных амплитуд и частот.
#
# Исходный сигнал описывается как функция времени. Преобразование Фурье представляет сигнал в виде амплитуды и функции частоты.

# %% [markdown]
# ![m8_14_image2.png](attachment:m8_14_image2.png)

# %% [markdown]
# Cигнал и его Фурье-образ

# %% [markdown]
# ![m8_14_image3.png](attachment:m8_14_image3.png)

# %% [markdown]
# Вейвлет-преобразование
#
# Преобразование Фурье не единственный способ разложить сигнал. Наиболее часто используемое преобразование после Фурье — это Вейвлет-преобразование.
#
# Вейвлет-преобразование, в отличие от преобразования Фурье, может использоваться при пространственном распределении сигнала.

# %% [markdown]
# ![m8_14_image4.png](attachment:m8_14_image4.png)

# %% [markdown]
# JPEG использует вейвлет-преобразование для сжатия изображений.
