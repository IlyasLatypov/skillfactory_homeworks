# %% [markdown]
# ## Pikabu-dataset

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ### Считываем и формируем датасет

# %%
headers=['story_title','link','story_id','data_rating','data_timestamp','story_comments','data_author_id','data_meta_rating','user_name','user_link','story__community_link']

# %%
df = pd.read_csv('400k-pikabu.csv',parse_dates=['data_timestamp'],
                   warn_bad_lines=True,
                   index_col = False,
                   #index_col='story_id',
                   dtype ={'story_title':'object','link':'object','story_id':'float32','data_rating':'float32',
                          'story_comments':'float32','data_author_id':'float32'},
                   delimiter='\t',names=headers)

# %%
print(df.shape)#468595 строк,11 столбцов
# Out:
# (468596, 11)

# %%
df.dtypes
# Out:
# story_title                      object
# link                             object
# story_id                        float32
# data_rating                     float32
# data_timestamp           datetime64[ns]
# story_comments                  float32
# data_author_id                  float32
# data_meta_rating                 object
# user_name                        object
# user_link                        object
# story__community_link            object
# dtype: object

# %%
df.head(5)
# Out:
#                                          story_title  \
# 0              Похоже я заболел коронавирусом... Ч.4
# 1  9 фактов об антибиотиках и резистентности к ни...
# 2  Как на меня повлиял карантин со всеми вытекающ...
# 3                                    После карантина
# 4                                 Очередная изоляция
#
#                                                 link   story_id  data_rating  \
# 0                                   /search?n=16&r=3  7305431.0       3023.0
# 1  https://pikabu.ru/story/9_faktov_ob_antibiotik...  7685627.0        121.0
# 2  https://pikabu.ru/story/kak_na_menya_povliyal_...  7683667.0        445.0
# 3    https://pikabu.ru/story/posle_karantina_7671502  7671502.0        636.0
# 4  https://pikabu.ru/story/ocherednaya_izolyatsiy...  7666363.0         73.0
#
#   data_timestamp  story_comments  data_author_id data_meta_rating   user_name  \
# 0     2020-03-21           503.0       2108995.0         3174:151  Redboy2605
# 1     2020-08-31            38.0       2731229.0        131:10:00     MedBred
# 2     2020-08-30            92.0       1665644.0        479:34:00   Enot22rus
# 3     2020-08-24             6.0         69845.0        670:34:00      SamDee
# 4     2020-08-21            22.0       2108995.0         87:14:00  Redboy2605
#
#       user_link story__community_link
# 0  /@Redboy2605                   NaN
# 1     /@MedBred                   NaN
# 2   /@Enot22rus                   NaN
# 3      /@SamDee     /community/comics
# 4  /@Redboy2605                   NaN

# %%
df.describe()
# Out:
#           story_id    data_rating  story_comments  data_author_id
# count   468557.000  464647.000000   467090.000000    4.671130e+05
# mean   6607088.000     758.906860       72.776642    1.786928e+06
# std    1147562.375    1650.449707      156.246887    9.393718e+05
# min          0.000   -5041.000000        0.000000    1.000000e+00
# 25%    6322141.000      13.000000        8.000000    9.952670e+05
# 50%    7105049.000     119.000000       22.000000    1.835065e+06
# 75%    7264153.000     702.000000       66.000000    2.637453e+06
# max    7690043.000   43047.000000     5000.000000    3.314452e+06

# %% [markdown]
# ### Работа с пустыми значениями

# %%
#смотрим количество пустых story_title
len(df.loc[pd.isnull( df['story_title'])])
# Out:
# 1444

# %%
#как это выглядит?
df.loc[pd.isnull( df['story_title'])]
# Out:
#        story_title                                               link  \
# 2779           NaN  https://russian.rt.com/russia/news/730656-zabo...
# 2828           NaN  https://pikabu.ru/story/otvet_na_post_yekstrem...
# 5362           NaN  https://pikabu.ru/story/otvet_na_post_borets_v...
# 8753           NaN  https://pikabu.ru/story/otvet_na_post_syurpriz...
# 9022           NaN  https://pikabu.ru/story/otvet_na_post_vspomnil...
# ...            ...                                                ...
# 467751         NaN  https://pikabu.ru/story/otvet_na_post_feminizm...
# 467920         NaN  https://fr.wikipedia.org/wiki/Joseph_Fran%C3%A...
# 468193         NaN  https://pikabu.ru/story/otvet_na_post_maksim_k...
# 468264         NaN                  https://egrul.nalog.ru/index.html
# 468554         NaN  https://pikabu.ru/story/otvet_na_post_proverka...
#
#          story_id  data_rating data_timestamp  story_comments  data_author_id  \
# 2779    7307377.0        249.0            NaT             NaN             NaN
# 2828    7308621.0       1118.0            NaT             NaN             NaN
# 5362    7314238.0         22.0            NaT             NaN             NaN
# 8753    7307264.0         24.0            NaT             NaN             NaN
# 9022    7306950.0        470.0            NaT             NaN             NaN
# ...           ...          ...            ...             ...             ...
# 467751  7394573.0         50.0            NaT             NaN             NaN
# 467920  7394594.0         11.0            NaT             NaN             NaN
# 468193  7394970.0       4080.0            NaT             NaN             NaN
# 468264  7395281.0          6.0            NaT             NaN             NaN
# 468554  7395114.0         22.0            NaT             NaN             NaN
#
#        data_meta_rating     user_name user_link story__community_link
# 2779                NaN   Ghost.Runet       NaN                   NaN
# 2828                NaN        almazD       NaN                   NaN
# 5362                NaN      Cthutq24       NaN                   NaN
# 8753                NaN    Solomon979       NaN                   NaN
# 9022                NaN  CubinskiyRom       NaN                   NaN
# ...                 ...           ...       ...                   ...
# 467751              NaN        SamSar       NaN                   NaN
# 467920              NaN      1valera1       NaN                   NaN
# 468193              NaN         50x50       NaN                   NaN
# 468264              NaN         Afn84       NaN                   NaN
# 468554              NaN       Mymbaka       NaN                   NaN
#
# [1444 rows x 11 columns]

# %%
#смотрим пустые значения в story_id
len(df.loc[pd.isnull( df['story_id'])])
# Out:
# 39

# %%
#удаляем строки с пропусками в story_id и story_title. то есть строки (axis=0), где пропусков 5 штук
data1=df.dropna(axis=0, thresh=5)

# %%
#проверяем
len(data1.loc[pd.isnull(data1['story_id'])])
# Out:
# 0

# %%
#осталась одна строка, но это не критично
len(data1.loc[pd.isnull( data1['story_title'] ) ])
# Out:
# 1

# %%
#удаление пустых строк никак почти никак не повлияло на показатели
data1.describe()
# Out:
#           story_id    data_rating  story_comments  data_author_id
# count   467113.000  463204.000000   467090.000000    4.671130e+05
# mean   6605166.500     760.325378       72.776649    1.786928e+06
# std    1148752.125    1651.541504      156.246887    9.393718e+05
# min     612623.000   -5041.000000        0.000000    1.000000e+00
# 25%    6317042.000      13.000000        8.000000    9.952670e+05
# 50%    7104429.000     119.000000       22.000000    1.835065e+06
# 75%    7264004.000     704.000000       66.000000    2.637453e+06
# max    7690043.000   43047.000000     5000.000000    3.314452e+06

# %% [markdown]
# ### Поработаем с датасетом

# %%
#посмотрим названия колонок
df.columns
# Out:
# Index(['story_title', 'link', 'story_id', 'data_rating', 'data_timestamp',
#        'story_comments', 'data_author_id', 'data_meta_rating', 'user_name',
#        'user_link', 'story__community_link'],
#       dtype='object')

# %%
#выберем первую колонку
col = df['story_title']
col
# Out:
# 0                     Похоже я заболел коронавирусом... Ч.4
# 1         9 фактов об антибиотиках и резистентности к ни...
# 2         Как на меня повлиял карантин со всеми вытекающ...
# 3                                           После карантина
# 4                                        Очередная изоляция
#                                 ...
# 468591                                  Первые ДТП в России
# 468592                                              Новости
# 468593    Рабочие устроили массовую драку на территории ...
# 468594                                         Сисяндопрель
# 468595                                       Будет или нет?
# Name: story_title, Length: 468596, dtype: object

# %%
data1.min()
# Out:
# link                            /@08g2s
# story_id                         612623
# data_rating                       -5041
# data_timestamp      2012-01-08 00:00:00
# story_comments                        0
# data_author_id                        1
# data_meta_rating                 #ЗНАЧ!
# user_name                    .MoonLight
# user_link                          /404
# dtype: object

# %%
data1.max()
# Out:
# link                https://южнаяволна.рф/news/federalnye-novosti/...
# story_id                                                  7.69004e+06
# data_rating                                                     43047
# data_timestamp                                    2020-12-08 00:00:00
# story_comments                                                   5000
# data_author_id                                            3.31445e+06
# data_meta_rating                                                 9:59
# user_name                                                      июл.92
# user_link                                                   /@zzzztop
# dtype: object

# %%
#то же самое более наглядно
data1.loc[:,['user_name', 'data_rating', 'story_comments']].min()
# Out:
# user_name         .MoonLight
# data_rating            -5041
# story_comments             0
# dtype: object

# %%
data1.loc[:,['user_name', 'data_rating', 'story_comments']].max()
# Out:
# user_name         июл.92
# data_rating        43047
# story_comments      5000
# dtype: object

# %%
#выберем из datasetа интересующие колонки
small_df = data1[['story_id', 'data_rating', 'data_timestamp','user_name']] 
print(small_df.head())
# Out:
#     story_id  data_rating data_timestamp   user_name
# 0  7305431.0       3023.0     2020-03-21  Redboy2605
# 1  7685627.0        121.0     2020-08-31     MedBred
# 2  7683667.0        445.0     2020-08-30   Enot22rus
# 3  7671502.0        636.0     2020-08-24      SamDee
# 4  7666363.0         73.0     2020-08-21  Redboy2605

# %%
#или так
data1.loc[:,['user_name', 'data_rating', 'story_comments']].head(n=3)
# Out:
#     user_name  data_rating  story_comments
# 0  Redboy2605       3023.0           503.0
# 1     MedBred        121.0            38.0
# 2   Enot22rus        445.0            92.0

# %%
#теперь соберем интересующие значения в массив
arr = data1[['story_id', 'data_rating', 'data_timestamp','user_name']].values

# %%
print(arr[0, 1])
# Out:
# 3023.0

# %%
arr[:, 1] #столбец рейтинг
# Out:
# array([3023.0, 121.0, 445.0, ..., 9.0, -3.0, 0.0], dtype=object)

# %%
#применим маску data_rating статьи больше 10000
mask = arr[:, 1] > 10000.0
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
print((arr[:, 1] > 10000.0).sum()) #количество строк(статей), где рейтинг статьи больше 10000
# Out:
# 2672
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Порисуем графики

# %%
import matplotlib.pyplot as plt

# %%
#если связь между id автора статьи и рейтингом статьи ?
plt.scatter(data1['data_author_id'], data1['data_rating'])
plt.xlabel('data_author_id') 
plt.ylabel('data_rating')
# Out:
# Text(0, 0.5, 'data_rating')

# %%
#если связь между id статьи и рейтингом статьи ?
plt.scatter(data1['story_id'], data1['data_rating'])
plt.xlabel('story_id') 
plt.ylabel('data_rating')
# Out:
# Text(0, 0.5, 'data_rating')

# %%
##если связь между датой статьи и рейтингом ?
plt.scatter(data1['data_timestamp'], data1['data_rating'])
plt.xlabel('data_timestamp') 
plt.ylabel('data_rating')
# Out:
# Text(0, 0.5, 'data_rating')

# %%
##если связь между рейтингом статьи и количеством комментов к ней?
plt.scatter(data1['story_comments'], data1['data_rating'])
plt.xlabel('story_comments') 
plt.ylabel('data_rating')
# Out:
# Text(0, 0.5, 'data_rating')

# %% [markdown]
# #### Попробуем другие инструменты визуализации.Например, seaborn.

# %%
# для установки библиотек
 ! pip3 install seaborn
 ! pip3 install plotly
 ! pip3 install ggplot
 ! pip3 install matplotlib

# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 6,3
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %config InlineBackend.figure_format = 'png' 
sns_plot = sns.pairplot(data1[['story_id', 'data_rating', 'story_comments']]);
sns_plot.savefig('pairplot.png')

# %%
df1 = data1[['data_rating'] + ['data_timestamp']].groupby('data_rating').sum()
df1.head()
# Out:
#             data_timestamp
# data_rating
# -5041.0         2020-03-26
# -4574.0         2020-11-04
# -2582.0         2020-04-03
# -2502.0         2020-04-03
# -2440.0         2020-04-03

# %%
ax = df1.data_timestamp.hist(bins=80)
ax.set_title('Распределение рейтинга статей')
ax.set_xlabel('даты')
ax.set_ylabel('рейтинг')
# Out:
# Text(0, 0.5, 'рейтинг')

# %%
top_users_df = data1.groupby('user_name')[['data_rating']].sum().sort_values('data_rating', ascending=False).head(10)   
top_users_df
# Out:
#               data_rating
# user_name
# DELETED         3524832.0
# kuchka70        3376110.0
# Deathman        3370440.0
# Prostoilogin    3215099.0
# iProcione       2123788.0
# alexmix         1806765.0
# PivBear         1475142.0
# Geekabu         1226272.0
# homerchick      1170854.0
# BAJANNN         1144858.0

# %%
top_users_df.style.bar()
# Out:
# <style  type="text/css" >
#     #T_3424eb22_f692_11ea_8185_005056c00008row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_3424eb22_f692_11ea_8185_005056c00008row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 93.8%, transparent 93.8%);
#         }    #T_3424eb22_f692_11ea_8185_005056c00008row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 93.5%, transparent 93.5%);
#         }    #T_3424eb22_f692_11ea_8185_005056c00008row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 87.0%, transparent 87.0%);
#         }    #T_3424eb22_f692_11ea_8185_005056c00008row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f
_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#сгруппируем по дате и суммарному рейтингу статей на эту дату
df2 = data1.groupby('data_timestamp')[['data_rating']].sum()
df2.head()
# Out:
#                 data_rating
# data_timestamp
# 2012-01-08           2245.0
# 2013-01-04          12721.0
# 2013-01-05           6030.0
# 2013-01-06           7932.0
# 2013-01-07          11230.0

# %%
#посмотрим, сколько статей всего выходило на определенную дату (месяц)
released_stories = data1.groupby('data_timestamp')[['story_id']].count()
released_stories.head()
# Out:
#                 story_id
# data_timestamp
# 2012-01-08             1
# 2013-01-04            14
# 2013-01-05            10
# 2013-01-06            12
# 2013-01-07            12

# %%
#склеим две таблицы
years_df = df2.join(released_stories)
years_df.head()
# Out:
#                 data_rating  story_id
# data_timestamp
# 2012-01-08           2245.0         1
# 2013-01-04          12721.0        14
# 2013-01-05           6030.0        10
# 2013-01-06           7932.0        12
# 2013-01-07          11230.0        12

# %%
#нарисуем в plotly

trace0 = go.Scatter(
    x=years_df.index,
    y=years_df.data_rating,
    name='data_rating'
)

trace1 = go.Scatter(
    x=years_df.index,
    y=years_df.story_id,
    name='story_id'
)

data = [trace0, trace1]
layout = {'title': 'Statistics'}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)
# Out:
# <div>
#
#
#             <div id="2e875e6f-c314-46b7-9063-3e5b2d154879" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e875e6f-c314-46b7-9063-3e5b2d154879")) {
#                     Plotly.newPlot(
#                         '2e875e6f-c314-46b7-9063-3e5b2d154879',
#                         [{"name": "data_rating", "type": "scatter", "x": ["2012-01-08T00:00:00", "2013-01-04T00:00:00", "2013-01-05T00:00:00", "2013-01-06T00:00:00", "2013-01-07T00:00:00", "2013-01-08T00:00:00", "2013-01-09T00:00:00", "2013-01-10T00:00:00", "2013-01-11T00:00:00", "2013-01-12T00:00:00", "2013-01-19T00:00:00", "2013-01-31T00:00:00", "2013-02-04T00:00:00", "2013-02-05T00:00:00", "2013-02-06T00:00:00", "2013-02-07T00:00:00", "2013-02-08T00:00:00", "2013-02-09T00:00:00", "2013-02-10T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-09T00:00:00", "2013-03-10T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-16T00:00:00", "2013-03-17T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-23T00:00:00", "2013-03-24T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-03-29T00:00:00", "2013-03-30T00:00:00", "2013-03-31T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-06T00:00:00", "2013-04-07T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-13T00:00:00", "2013-04-14T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2
data1['user_name'].value_counts()
# Out:
# DELETED           4882
# kuchka70          2498
# Prostoilogin      1533
# alexmix           1477
# Deathman          1412
#                   ...
# imastark             1
# justseeit            1
# NekroMMC             1
# dimatolstyakov       1
# Zasvetka             1
# Name: user_name, Length: 123406, dtype: int64

# %%
#кто пишет часто? более 500 статей
for i in data1.groupby('user_name').size():
    if i>500:        
        print (data1.iloc[i,8],i) #8-номер столбца с user_name
# Out:
# crackcraft 531
# mpazzz 568
# kastamurzik 589
# pbdsu 773
# RedCatBlackFox 4882
# Wishhnya 1412
# haalward 1190
# iProcione 690
# tooNormal 651
# Drugayakuhnya 566
# Ozzyab 1088
# kalinkaElena9 711
# Freshik04 665
# 100pudofff 905
# 100pudofff 1251
# Elvina.Brestel 1533
# 1570525 543
# Samorodok 597
# Mr.Kolyma 592
# kka2012 505
# DENTAARIUM 963
# 4nat1k 600
# chaserLI 650
# kostas26 1192
# portal13 895
# exJustice 1477
# alc19 525
# kuchka70 572
# SovietPosters 781
# Grand.Bro 1051
# Rogo3in 1068
# fylhtq2222 774
# deystvitelno 539
# lilo26 802
# al56.81 2498
# Hebrew01 596
# TheRovsh 803
# ToBapuLLI 1143
# ragnarok777 893
# Ichizon 890
# hoks1 610
# arthik 700

# %%
#посмотрим сколько статей от различных коммюнити
data1.groupby('story__community_link').size()
# Out:
# story__community_link
# /community/                      1
# /community/1914                 15
# /community/1C8                  14
# /community/40000_pododeyalko     2
# /community/4inovniki            19
#                                 ..
# /community/yozhiki              21
# /community/zapchasti             7
# /community/zarplata             28
# /community/zoo                  60
# /community/zootopia             86
# Length: 629, dtype: int64

# %%
data1['story__community_link'].value_counts()
# Out:
# /community/reposts              17028
# /community/kotiki_obormotiki    10533
# /community/comics                7242
# /community/hand_made             5987
# /community/photographers         5495
#                                 ...
# /community/bollywoodnews            1
# /community/Epic_life                1
# /community/Mercenaries              1
# /community/villageUSA               1
# /community/IDL                      1
# Name: story__community_link, Length: 629, dtype: int64

# %%
data1['story__community_link'].describe()
# Out:
# count                 181608
# unique                   629
# top       /community/reposts
# freq                   17028
# Name: story__community_link, dtype: object

# %%
for i in data1.groupby('story__community_link').size(): #количество статей от коммьюнити
    if i>100:        
        print (data1.iloc[i,10],i)
# Out:
# /community/aibolit 300
# /community/soft 150
# nan 494
# nan 3309
# nan 1313
# /community/story 116
# nan 774
# /community/roadaccident 103
# /community/child 111
# /community/reposts 339
# nan 149
# nan 302
# /community/Art 762
# nan 112
# /community/kotiki_obormotiki 272
# /community/bigcollection 120
# nan 115
# /community/ibc 153
# /community/comics 535
# /community/dogs_weekdays 318
# /community/comics 536
# nan 136
# nan 424
# /community/books 845
# /community/true_story 166
# nan 158
# /community/spacex 4328
# nan 138
# /community/cosplay 350
# /community/dogs_weekdays 175
# nan 118
# nan 125
# /community/poezda 653
# /community/child 111
# nan 195
# nan 622
# nan 397
# /community/kotiki_obormotiki 329
# nan 134
# /community/kotiki_obormotiki 340
# /community/true_story 193
# nan 104
# nan 390
# /community/Far_East 230
# /community/kancolle 877
# nan 117
# nan 5217
# /community/true_story 193
# nan 718
# /community/comics 227
# nan 400
# nan 136
# /community/novosti 145
# nan 2357
# nan 1305
# nan 146
# /community/kotiki_obormotiki 181
# nan 399
# nan 216
# nan 2527
# nan 409
# nan 564
# nan 167
# nan 475
# nan 222
# /community/kotiki_obormotiki 1716
# nan 151
# nan 263
# /community/medic 468
# nan 171
# /community/reposts 156
# nan 395
# nan 280
# /community/AviaTech 894
# /community/steam 363
# nan 7242
# /community/Art 754
# nan 115
# nan 107
# /community/dogs_weekdays 179
# /community/bigcollection 120
# /community/novosti 209
# /community/antimoshennic 113
# /community/reposts 373
# nan 149
# /community/reposts 3620
# nan 133
# /community/dogs_weekdays 318
# nan 583
# nan 1207
# nan 302
# /community/bigcollection 647
# /community/kotiki_obormotiki 181
# /community/reposts 373
# nan 139
# nan 421
# /community/photographers 260
# nan 218
# nan 323
# /community/LeagueOfArtists 283
# nan 157
# nan 1214
# /community/auto 3696
# nan 212
# nan 106
# nan 147
# nan 134
# nan 624
# nan 5987
# /community/dogs_weekdays 174
# nan 2192
# /community/agriculture 197
# /community/kotiki_obormotiki 270
# nan 242
# nan 216
# /community/fakes 676
# nan 288
# /community/aww 2362
# /community/comics 517
# /community/hand_made 1232
# nan 172
# nan 146
# /community/steam 10533
# nan 417
# nan 314
# nan 154
# /community/antimoshennic 148
# /community/reposts 204
# /community/Art 856
# /community/story 121
# nan 610
# /community/reposts 339
# nan 115
# /community/LeagueOfArtists 284
# nan 1432
# /community/true_story 401
# nan 254
# nan 118
# nan 125
# nan 152
# nan 3283
# nan 132
# nan 112
# nan 149
# nan 466
# nan 233
# /community/dogs_weekdays 175
# /community/dogs_weekdays 184
# nan 207
# nan 2421
# nan 208
# /community/data 524
# nan 221
# nan 135
# nan 5495
# nan 1056
# nan 110
# nan 298
# nan 463
# nan 821
# nan 628
# nan 126
# nan 371
# /community/LeagueOfArtists 293
# /community/reposts 156
# nan 147
# /community/football 1095
# /community/reposts 514
# /community/postapocalypse 119
# nan 154
# nan 104
# nan 1313
# nan 17028
# nan 105
# nan 195
# nan 236
# nan 152
# /community/pobeda 1191
# nan 712
# nan 264
# nan 582
# nan 104
# nan 216
# nan 498
# nan 1397
# nan 202
# nan 1983
# nan 254
# /community/kotiki_obormotiki 434
# nan 2197
# /community/dogs_weekdays 187
# nan 107
# nan 1773
# nan 345
# /community/retro 635
# /community/reposts 469
# /community/agriculture 200
# /community/bigcollection 644
# /community/electrician 414
# /community/novosti 309
# /community/baikal 2705
# /community/agriculture 199
# /community/cgimedia 849
# nan 374
# nan 600
# nan 117
# nan 296
# /community/reposts 339
# /community/alcobushnik 386
# nan 114
# /community/kotiki_obormotiki 5331
# /community/comics 2691
# nan 1257
# nan 102
# /community/antimoshennic 148
# /community/shkololo 1488
# /community/fox 189

# %% [markdown]
# ### Применение функций с вынесением результата в отдельный столбец

# %%
def ratingGroup( row ):
    """
    Простая функция отнесения рейтинга статьи к группе
    Если рейтинг больше < 5000 - bad, > 5000 - good
    """
        # проверяем, что значение рейтинга не равно NaN
    if not pd.isnull( row['data_rating'] ):
        if row['data_rating'] <= 5000:
            return 'bad'

        if row['data_rating'] >= 20000:
            return 'good'        
    
    # если значение возраста NaN, то возвращаем Undef
    return 'Undef'

# %%
# применим функцию ratingGroup к DataFrame и выведем результат в отдельный столбец ratingGroup

data1['ratingGroup'] = data1.apply( ratingGroup, axis = 1 )
data1.head(10)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                          story_title  \
# 0              Похоже я заболел коронавирусом... Ч.4
# 1  9 фактов об антибиотиках и резистентности к ни...
# 2  Как на меня повлиял карантин со всеми вытекающ...
# 3                                    После карантина
# 4                                 Очередная изоляция
# 5                    В шкуре красавчика. Хотя бы так
# 6                               Перу, опять карантин
# 7            Рост зараженных коронавирусом в Испании
# 8                                      В продолжение
# 9                        Про Covid и Нижний Новгород
#
#                                                 link   story_id  data_rating  \
# 0                                   /search?n=16&r=3  7305431.0       3023.0
# 1  https://pikabu.ru/story/9_faktov_ob_antibiotik...  7685627.0        121.0
# 2  https://pikabu.ru/story/kak_na_menya_povliyal_...  7683667.0        445.0
# 3    https://pikabu.ru/story/posle_karantina_7671502  7671502.0        636.0
# 4  https://pikabu.ru/story/ocherednaya_izolyatsiy...  7666363.0         73.0
# 5  https://pikabu.ru/story/v_shkure_krasavchika_k...  7656287.0       1241.0
# 6  https://pikabu.ru/story/peru_opyat_karantin_76...  7655556.0       1225.0
# 7  https://pikabu.ru/story/rost_zarazhennyikh_kor...  7655533.0         34.0
# 8     https://pikabu.ru/story/v_prodolzhenie_7652007  7652007.0        231.0
# 9  https://pikabu.ru/story/pro_covid_i_nizhniy_no...  7649049.0       2239.0
#
#   data_timestamp  story_comments  data_author_id data_meta_rating   user_name  \
# 0     2020-03-21           503.0       2108995.0         3174:151  Redboy2605
# 1     2020-08-31            38.0       2731229.0        131:10:00     MedBred
# 2     2020-08-30            92.0       1665644.0        479:34:00   Enot22rus
# 3     2020-08-24             6.0         69845.0        670:34:00      SamDee
# 4     2020-08-21            22.0       2108995.0         87:14:00  Redboy2605
# 5     2020-08-17            52.0       2366294.0       1279:38:00     Firbolg
# 6     2020-08-16           119.0       2605126.0       1250:25:00    Tornillo
# 7     2020-08-16            11.0       3229808.0         40:06:00    aJournal
# 8     2020-08-14            22.0        307998.0        259:28:00  Djanena4ka
# 9     2020-08-13           279.0       1993988.0          2319:80     Hahaker
#
#       user_link          story__community_link ratingGroup
# 0  /@Redboy2605                            NaN         bad
# 1     /@MedBred                            NaN         bad
# 2   /@Enot22rus                            NaN         bad
# 3      /@SamDee              /community/comics         bad
# 4  /@Redboy2605                            NaN         bad
# 5     /@Firbolg                            NaN         bad
# 6    /@Tornillo  /community/pikabushniki_vezde         bad
# 7    /@aJournal  /community/pikabushniki_vezde         bad
# 8  /@Djanena4ka                            NaN         bad
# 9     /@Hahaker                            NaN         bad
