# %%
import pandas as pd

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
data.loc["Первый"]
# Out:
# 'Январь'

# %%
data.loc[["Первый", "Третий"]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
data.iloc[[0, 2]]
# Out:
# Первый    Январь
# Третий      Март
# dtype: object

# %%
"""
Создайте Series, содержащий цифры от 10 до 1000 ( data = pd.Series(list(range(10, 1001))) ).

Что выведет на экран следующий код: print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])?

"""

data = pd.Series(list(range(10, 1001)))

print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
data = pd.Series(list(range(10, 1001)))
display(data)
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
#        ...
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
                  columns = ['foo', 'bar', 'baz'], 
                  index = ['foobar', 'foobaz'])
display(df)
# Out:
#         foo  bar  baz
# foobar    1    2    3
# foobaz    2    3    4

# %%
football = pd.read_csv('data_sf.csv')
display(football.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
football = pd.read_csv('data_sf.csv')
display(football.tail(7))
# Out:
#        Unnamed: 0                Name  Age          Nationality  \
# 12890       13119            J. Young   18             Scotland
# 12891       13120            D. Walsh   18  Republic of Ireland
# 12892       13121        J. Lundstram   19              England
# 12893       13122  N. Christoffersson   19               Sweden
# 12894       13123           B. Worman   16              England
# 12895       13124      D. Walker-Rice   17              England
# 12896       13125           G. Nugent   16              England
#
#                    Club    Value  Wage Position  Crossing  Finishing  ...  \
# 12890      Swindon Town   450000  1000       ST        28         47  ...
# 12891      Waterford FC    60000  1000       RB        22         23  ...
# 12892   Crewe Alexandra  1100000  1000       CM        34         38  ...
# 12893    Trelleborgs FF    60000  1000       ST        23         52  ...
# 12894  Cambridge United    60000  1000       ST        25         40  ...
# ...

# %%
football = pd.read_csv('data_sf.csv')
display(football.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football = pd.read_csv('data_sf.csv')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.Wage.sum()
# Out:
# 96954000

# %%
football = pd.read_csv('data_sf.csv')
football.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
football[football.Age > 20]
# Out:
#        Unnamed: 0               Name  Age Nationality  \
# 0               0           L. Messi   31   Argentina
# 1               1  Cristiano Ronaldo   33    Portugal
# 2               2          Neymar Jr   26      Brazil
# 3               3             De Gea   27       Spain
# 4               4       K. De Bruyne   27     Belgium
# ...           ...                ...  ...         ...
# 12838       13067          D. Mackay   21    Scotland
# 12857       13086             Wu Lei   21    China PR
# 12861       13090        Y. Uchimura   33       Japan
# 12870       13099           M. Hurst   22    Scotland
# 12873       13102      K. Pilkington   44     England
#
#                              Club      Value    Wage Position  Crossing  \
# 0                    FC Barcelona  110500000  565000       RF        84
# 1                        Juventus   77000000  405000       ST        84
# 2             Paris Saint-Germain  118500000  290000       LW        79
# ...

# %%
football[(football.Club == 'FC Barcelona')]
# Out:
#       Unnamed: 0             Name  Age  Nationality          Club      Value  \
# 0              0         L. Messi   31    Argentina  FC Barcelona  110500000
# 7              7        L. Suárez   31      Uruguay  FC Barcelona   80000000
# 18            18    M. ter Stegen   26      Germany  FC Barcelona   58000000
# 20            20  Sergio Busquets   29        Spain  FC Barcelona   51500000
# 32            32         Coutinho   26       Brazil  FC Barcelona   69500000
# 42            42        S. Umtiti   24       France  FC Barcelona   57000000
# 49            49       Jordi Alba   29        Spain  FC Barcelona   38000000
# 53            53       I. Rakitić   30      Croatia  FC Barcelona   46500000
# 54            54            Piqué   31        Spain  FC Barcelona   34000000
# 96            96         A. Vidal   31        Chile  FC Barcelona   26000000
# 141          141       O. Dembélé   21       France  FC Barcelona   40000000
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
football[(football.Wage > football.Wage.mean())].SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
football[(football.Wage < football.Wage.mean())].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
football[(football.Wage == football.Wage.max())]
# Out:
#    Unnamed: 0      Name  Age Nationality          Club      Value    Wage  \
# 0           0  L. Messi   31   Argentina  FC Barcelona  110500000  565000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
#
#    GKPositioning  GKReflexes
# 0             14           8
#
# [1 rows x 42 columns]

# %%
football[(football.Nationality == 'Brazil')].Penalties.sum()
# Out:
# 22789

# %%
football[(football.HeadingAccuracy > 50)].Age.mean()
# Out:
# 25.58771113179944

# %%
football[(football.Composure > 0.9*football.Composure.max())&(football.Reactions > 0.9*football.Reactions.max())].Age.min()
# Out:
# 24

# %%
football[(football.Age == football.Age.max())].Reactions.mean() - football[(football.Age == football.Age.min())].Reactions.mean()
# Out:
# 22.642857142857146

# %%
football[(football.Value > football.Value.mean())].Nationality.describe()
# Out:
# count      1747
# unique       98
# top       Spain
# freq        211
# Name: Nationality, dtype: object

# %%
football[(football.Position == 'GK')&(football.GKReflexes == football.GKReflexes.max())].Wage.mean() / football[(football.GKHandling == football.GKHandling.max())].Wage.mean()
# Out:
# 2.765957446808511

# %%
"""
Определите, во сколько раз средняя сила удара (ShotPower) самых агрессивных игроков (игроков с максимальным
значением показателя "Агрессивность" (Aggression)) выше средней силы удара игроков с минимальной агрессией.

Ответ округлите до сотых.

"""

football[(football.Aggression == football.Aggression.max())].ShotPower.mean() / football[(football.Aggression == football.Aggression.min())].ShotPower.mean()
# Out:
# 2.076923076923077

# %%
s = football['Club'].value_counts()
display(s)
# Out:
# Shonan Bellmare      30
# V-Varen Nagasaki     30
# FC Emmen             29
# De Graafschap        29
# Vissel Kobe          29
#                      ..
# Olympiacos CFP        8
# Dinamo Zagreb         7
# GD Chaves             7
# Vitória Guimarães     7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
s = football['Position'].value_counts(normalize=True)
display(s)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
small_df = football[football.columns[0:7]].head(25)
display(small_df)
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
#     Unnamed: 0               Name  Age Nationality                 Club  \
# 0            0           L. Messi   31   Argentina         FC Barcelona
# 1            1  Cristiano Ronaldo   33    Portugal             Juventus
# 2            2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3            3             De Gea   27       Spain    Manchester United
# 4            4       K. De Bruyne   27     Belgium      Manchester City
# 5            5          E. Hazard   27     Belgium              Chelsea
# 6            6          L. Modrić   32     Croatia          Real Madrid
# 7            7          L. Suárez   31     Uruguay         FC Barcelona
# 8            8       Sergio Ramos   32       Spain          Real Madrid
# 9            9           J. Oblak   25    Slovenia      Atlético Madrid
# 10          10     R. Lewandowski   29      Poland    FC Bayern München
# 11          11           T. Kroos   28     Germany          Real Madrid
# ...

# %%
s = small_df['Wage'].value_counts()
display(s)
s.index
# Out:
# 205000    3
# 355000    2
# 240000    2
# 300000    1
# 130000    1
# 225000    1
# 455000    1
# 340000    1
# 315000    1
# 565000    1
# 405000    1
# 215000    1
# 380000    1
# 285000    1
# 145000    1
# 290000    1
# 125000    1
# 200000    1
# 420000    1
# 94000     1
# 260000    1
# Name: Wage, dtype: int64
# Int64Index([205000, 355000, 240000, 300000, 130000, 225000, 455000, 340000,
#             315000, 565000, 405000, 215000, 380000, 285000, 145000, 290000,
#             125000, 200000, 420000,  94000, 260000],
#            dtype='int64')

# %%
s.index[3]
# Out:
# 300000

# %%
s.index[0].left
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-9fe7ed825ec5> in <module>
# ----> 1 s.index[0].left
#
# AttributeError: 'numpy.int64' object has no attribute 'left'

# %%
s.index[0].right
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-7184fdd8c5d8> in <module>
# ----> 1 s.index[0].right
#
# AttributeError: 'numpy.int64' object has no attribute 'right'

# %%
small_df['Wage'] > s.index[3].left
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-92c00530cdaf> in <module>
# ----> 1 small_df['Wage'] > s.index[3].left
#
# AttributeError: 'numpy.int64' object has no attribute 'left'

# %%
s = football['FKAccuracy'].value_counts(bins=5)
display(s)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
result = football['Position'].nunique()
display(result)
# Out:
# 27

# %%
result = len(football['Position'].unique())
display(result)
# Out:
# 27

# %%
result = football['Position'].unique()
display(result)
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
result = football['Position'].count()
display(result)
# Out:
# 12897

# %%
result = len(football['Position'].value_counts())
display(result)
# Out:
# 27

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1     Uruguay            3
# 2     Germany            3
# 3     Belgium            3
# 4   Argentina            3
# 5      France            2
# 6    Slovenia            1
# 7     England            1
# 8     Croatia            1
# 9       Italy            1
# 10     Poland            1
# 11     Brazil            1
# 12   Portugal            1

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Uruguay              3
# 2      Germany              3
# 3      Belgium              3
# 4    Argentina              3
# 5       France              2
# 6     Slovenia              1
# 7      England              1
# 8      Croatia              1
# 9        Italy              1
# 10      Poland              1
# 11      Brazil              1
# 12    Portugal              1

# %%
"""
У какого процента испанских специалистов (Nationality = 'Spain') зарплата (Wage) находится в пределах
25% минимума от наблюдаемого уровня зарплат? Ответ дайте в виде целого числа (округлите полученный результат) без знака %.

Подсказка: Для решения задачи используйте value_counts() с параметром bins = 4.

"""

# s = football['Wage'].value_counts(bins=4)
# display(s)

# spains_min_wage = football.loc[(football['Wage'] > s.index[0].left) & (football['Wage'] < s.index[0].right) & (football.Nationality == 'Spain')]

# spains_all = football.loc[(football.Nationality == 'Spain')]

# display(len(spains_min_wage))
# display(len(spains_all))

# (len(spains_min_wage) / len(spains_all)) * 100

round((football[(football.Nationality == 'Spain')].Wage.value_counts(normalize=True, bins=4))*100, 0)
# Out:
# (620.999, 95750.0]      97.0
# (95750.0, 190500.0]      2.0
# (190500.0, 285250.0]     1.0
# (285250.0, 380000.0]     0.0
# Name: Wage, dtype: float64

# %%
"""
Укажите количество уникальных сборных (Nationality),
к которым относятся футболисты, выступающие за клуб (Club) "Manchester United".

"""

football_mc_club = football[(football.Club == 'Manchester United')]
display(football_mc_club)

football_mc_club['Nationality'].nunique()
# Out:
#       Unnamed: 0             Name  Age  Nationality               Club  \
# 3              3           De Gea   27        Spain  Manchester United
# 45            45         P. Pogba   25       France  Manchester United
# 47            47        R. Lukaku   25      Belgium  Manchester United
# 93            93       A. Sánchez   29        Chile  Manchester United
# 116          116       A. Martial   22       France  Manchester United
# 127          127         N. Matić   29       Serbia  Manchester United
# 231          231      M. Rashford   20      England  Manchester United
# 238          238        E. Bailly   24  Ivory Coast  Manchester United
# 263          263      C. Smalling   28      England  Manchester United
# 276          276      A. Valencia   32      Ecuador  Manchester United
# 335          336        S. Romero   31    Argentina  Manchester United
# 394          397          M. Rojo   28    Argentina  Manchester United
# ...

# %%
"""
С помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), выступающих за клуб (Club) 'Juventus'.

Перечислите их имена (Name, как в датафрейме) через запятую в алфавитном порядке.

"""

football[(football.Nationality == 'Brazil') & (football.Club == 'Juventus')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
"""
Укажите, какой из клубов (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет.


"""

football[(football.Age > 35)].Club.value_counts()
# Out:
# Hokkaido Consadole Sapporo    4
# Club Atlético Huracán         4
# Club Atlético Colón           3
# Hammarby IF                   3
# Club Atlético Talleres        3
#                              ..
# SPAL                          1
# Yokohama F. Marinos           1
# New York City FC              1
# IFK Göteborg                  1
# Kristiansund BK               1
# Name: Club, Length: 212, dtype: int64

# %%
"""
С помощью функции value_counts с параметром bins разбейте всех футболистов сборной (Nationality) Аргентины ('Argentina')
на 4 равные группы.
Укажите, сколько футболистов в возрасте от 34.75 до 41 года в сборной Аргентины.

"""

football[(football.Nationality == 'Argentina')].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
"""
Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст (Age) 21 год?

Введите с точностью до 2 знаков после запятой без указания знака % (например, 12.35).

"""

football[(football.Nationality == 'Spain')].Age.value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
grouped_df = football.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = football.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
grouped_df = football.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(10))
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# Name: Wage, dtype: int64

# %%
"""
Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position).
Представители какой позиции имеют самую высокую среднюю цену?
"""

grouped_df = football.groupby(['Position'])[['Wage','Value']].mean()
print(grouped_df.head(10))
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %%
football.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
football.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
football.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
football.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg     92
# 1. FC Heidenheim 1846    86
# 1. FC Kaiserslautern     85
# 1. FC Köln               76
# 1. FC Magdeburg          86
#                          ..
# Zagłębie Sosnowiec       84
# Çaykur Rizespor          81
# Örebro SK                85
# Östersunds FK            88
# Śląsk Wrocław            85
# Name: Strength, Length: 650, dtype: int64

# %%
football.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    22
# 1. FC Kaiserslautern     29
# 1. FC Köln               31
# 1. FC Magdeburg          19
#                          ..
# Zagłębie Sosnowiec       28
# Çaykur Rizespor          39
# Örebro SK                34
# Östersunds FK            32
# Śląsk Wrocław            31
# Name: Balance, Length: 650, dtype: int64

# %%
"""
Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club).
В скольких клубах средняя и медианная зарплаты совпадают?

Подсказка: чтобы в процессе группировки применить к данным одновременно две агрегирующие функции,
необходимо указать их как аргументы метода agg:

df.groupby(столбец_для_группировки)[столбцы_для_отображения].agg(['функция_1', 'функция_2'])

"""

count = 0

for mean, median in football.groupby(['Club'])['Wage'].agg(['mean', 'median']).values:
    if int(mean) == (median):
        count += 1
        
print(count)
# Out:
# 52

# %%
"""
Продолжаем работать с клубами, в которых средняя зарплата совпадает с медианной.
Каков максимальный размер средней зарплаты в этой группе клубов?

"""


f_temp = football.groupby(['Club'])['Wage'].agg(['mean', 'median'])

print(f_temp)



f_temp[f_temp['mean'] == f_temp['median']]['mean']
# Out:
#                               mean  median
# Club
#  SSV Jahn Regensburg   3750.000000    3500
# 1. FC Heidenheim 1846  3800.000000    3000
# 1. FC Kaiserslautern   1434.782609    1000
# 1. FC Köln             9200.000000    4000
# 1. FC Magdeburg        4000.000000    4000
# ...                            ...     ...
# Zagłębie Sosnowiec     1080.000000    1000
# Çaykur Rizespor        5363.636364    4500
# Örebro SK              1384.615385    1000
# Östersunds FK          1950.000000    1000
# Śląsk Wrocław          2083.333333    2000
#
# [650 rows x 2 columns]
# Club
# 1. FC Magdeburg            4000.0
# AEK Athens                 1000.0
# AJ Auxerre                 2000.0
# Benevento                  2000.0
# Bohemian FC                1000.0
# Boyacá Chicó FC            1000.0
# Bray Wanderers             1000.0
# Brøndby IF                 6000.0
# CD Feirense                4000.0
# CD Tondela                 2000.0
# Cork City                  1000.0
# ...

# %%
"""
С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea".

"""
# football[(football.Nationality == 'Spain')].Age.value_counts(normalize=True)

f_temp = football[(football.Club == 'Chelsea')].groupby(['Club'])['Wage'].agg('sum').sort_values(ascending=False)

print(f_temp)
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %%
"""
Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 20 лет.

"""

f_temp = football[(football.Nationality == 'Argentina') & (football.Age == 20)].groupby(['Club'])['Wage'].agg('max').sort_values(ascending=False)

print(f_temp)
# Out:
# Club
# Inter                          54000
# Racing Club                    11000
# San Lorenzo de Almagro          7000
# Defensa y Justicia              7000
# Estudiantes de La Plata         3000
# Portland Timbers                3000
# Club Atlético Tigre             3000
# Vélez Sarsfield                 2000
# Belgrano de Córdoba             2000
# Boca Juniors                    2000
# Club Atlético Banfield          2000
# Club Atlético Colón             2000
# Club Atlético Huracán           2000
# Club Atlético Talleres          2000
# Gimnasia y Esgrima La Plata     2000
# Genoa                           2000
# Unión de Santa Fe               2000
# Godoy Cruz                      2000
# Newell's Old Boys               2000
# Patronato                       2000
# River Plate                     2000
# Rosario Central                 2000
# Argentinos Juniors              2000
# Puebla FC                       1000
# CD O'Higgins                    1000
# ...

# %%
"""
Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 30 лет.

"""

f_temp = football[(football.Nationality == 'Argentina') & (football.Age == 30)].groupby(['Club'])['Wage'].agg('max').sort_values(ascending=False)

print(f_temp)
# Out:
# Club
# Manchester City                300000
# Milan                          245000
# Atalanta                        53000
# Nottingham Forest               35000
# Sevilla FC                      31000
# River Plate                     28000
# Dalian YiFang FC                22000
# Club Tijuana                    22000
# Club Atlético Lanús             10000
# Real Oviedo                      9000
# Tiburones Rojos de Veracruz      8000
# San Martín de San Juan           7000
# Club Atlético Tigre              6000
# Vélez Sarsfield                  6000
# San Martin de Tucumán            6000
# Newell's Old Boys                6000
# Rosario Central                  3000
# Belgrano de Córdoba              3000
# CD Antofagasta                   2000
# Deportes Iquique                 2000
# Atlético Huila                   1000
# Name: Wage, dtype: int64

# %%
"""
Определите максимальную силу (Strength) и баланс (Balance) среди игроков клуба (Club) "FC Barcelona" из Аргентины ("Argentina").
Ответ введите через точку с запятой без пробела.

"""

import sys

f_temp = football[(football.Nationality == 'Argentina') & (football.Club == 'FC Barcelona')].groupby(['Club'])[['Strength', 'Balance']].apply(max).sort_values(by='Balance', ascending=False)

print(f_temp)
# Out:
#               Strength  Balance
# Club
# FC Barcelona        59       95

# %%
pivot = football.loc[football['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
"""
Получаем из этой таблицы информацию о максимальной зарплате вратаря (GK), играющего за футбольный клуб "Manchester City"
"""

df2 = football.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')

df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot = football.loc[football['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid All
# Nationality
# Argentina                     1        1                 2           0   4
# Belgium                       1        0                 1           1   3
# Bosnia Herzegovina            0        1                 0           0   1
# Brazil                        2        2                 1           2   7
# Chile                         1        0                 1           0   2
# Costa Rica                    0        0                 0           1   1
# Croatia                       1        1                 0           1   3
# Dominican Republic            0        0                 0           1   1
# Ecuador                       0        0                 1           0   1
# England                       0        0                 6           0   6
# France                        3        1                 2           3   9
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
"""
Создайте сводную таблицу, содержащую сведения о количестве игроков, занимающих разные позиции в каждом клубе.
Отсутствующие значения замените нулями.

Каково среднее количество вратарей (GK) в клубе? Ответ округлите до трёх цифр после запятой.

"""

df3 = football.pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
margins=True,
fill_value=0)
display(df3)
# Out:
#                       Name                                 ...                 \
# Position               CAM CB CDM CF CM GK LAM LB LCB LCM  ... RB RCB RCM RDM
# Club                                                       ...
#  SSV Jahn Regensburg     0  5   1  0  2  3   0  2   0   0  ...  2   1   0   1
# 1. FC Heidenheim 1846    1  3   0  0  1  2   0  2   1   0  ...  2   1   0   0
# 1. FC Kaiserslautern     0  3   3  0  0  3   0  2   1   0  ...  2   0   0   1
# 1. FC Köln               0  1   1  0  2  3   0  0   0   0  ...  1   0   0   0
# 1. FC Magdeburg          0  4   0  1  0  3   0  1   1   1  ...  0   1   1   0
# ...                    ... ..  .. .. .. ..  .. ..  ..  ..  ... ..  ..  ..  ..
# Zagłębie Sosnowiec       3  2   2  0  0  3   0  3   1   0  ...  1   1   0   1
# Çaykur Rizespor          1  2   5  0  0  3   0  2   1   0  ...  3   0   0   1
# Örebro SK                0  4   0  0  1  3   0  0   1   1  ...  0   1   1   0
# ...

# %%
df = pd.read_csv('data_sf.csv')
pivot = df.loc[df['Position'].isin(df['Position'].unique())].pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
margins=True,
fill_value = 0)

mean_GK = pivot.loc['All']['Name']['GK']/(len(pivot.index) - 1) # Среднее количество GK в клубе

display(mean_GK)
# Out:
# 2.5246153846153847

# %%
"""
Используя таблицу, созданную на предыдущем шаге, определите, сколько клубов не содержат данных
о центральных полузащитниках. (CM)

Подсказка: для выполнения этого задания желательно сохранить сводную таблицу в виде отдельного датафрейма и сгруппировать часть
данных этого датафрейма с помощью value_counts().

"""

df = pd.read_csv('data_sf.csv')

pivot = df.loc[df['Position'].isin(df['Position'].unique())].pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
margins=True,
fill_value = 0)

# from Pivot Table to DataFrame

pivot.columns = pivot.columns.droplevel(0) #remove amount
pivot.columns.name = None               #remove categories
df = pivot.reset_index()                #index to columns

display(df)

display(df['CM'].value_counts())
# Out:
#                       Club  CAM    CB  CDM  CF    CM    GK  LAM    LB  LCB  \
# 0      SSV Jahn Regensburg    0     5    1   0     2     3    0     2    0
# 1    1. FC Heidenheim 1846    1     3    0   0     1     2    0     2    1
# 2     1. FC Kaiserslautern    0     3    3   0     0     3    0     2    1
# 3               1. FC Köln    0     1    1   0     2     3    0     0    0
# 4          1. FC Magdeburg    0     4    0   1     0     3    0     1    1
# ..                     ...  ...   ...  ...  ..   ...   ...  ...   ...  ...
# 646        Çaykur Rizespor    1     2    5   0     0     3    0     2    1
# 647              Örebro SK    0     4    0   0     1     3    0     0    1
# 648          Östersunds FK    1     1    0   1     3     3    0     2    1
# 649          Śląsk Wrocław    0     1    3   0     1     3    0     2    1
# 650                    All  633  1403  691  51  1067  1641    6  1002  409
#
#      ...  RCB  RCM  RDM  RF   RM   RS   RW  RWB    ST    All
# ...

# %%
"""
С помощью сводной таблицы и функции loc посчитайте,
сколько получают ("Wage") русские футболисты ("Russia"), играющие за ФК "AS Monaco".

"""

df = pd.read_csv('data_sf.csv')

pivot = football.loc[(football['Nationality'].isin(['Russia'])) & (football['Club'].isin(['AS Monaco']))].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)

display(pivot)
# Out:
#                  Wage
# Club        AS Monaco    All
# Nationality
# Russia          61000  61000
# All             61000  61000

# %%
"""
Создайте сводную таблицу, содержащую сведения о средней скорости футболистов,
занимающих разные позиции (Position) в разных футбольных клубах (Club).

Основываясь на данных таблицы, отметьте три позиции, представители которых в среднем обладают самой высокой скоростью.

"""

df = pd.read_csv('data_sf.csv')

pivot = df.loc[(df['Position'].isin(['ST'])) & (df['Club'].isin(['Sydney FC', 'CD Lugo', 'Arsenal', 'Toronto FC','Girona FC', 'Melbourne Victory', 'Vitória']))].pivot_table(values=['SprintSpeed'],
index=['Club'],
columns=['Position'],
aggfunc='mean',
margins=True)

display(pivot)

df = pivot.reindex(pivot['SprintSpeed'].sort_values(by='ST', ascending=False).index)


display(df)
# Out:
#                   SprintSpeed
# Position                   ST    All
# Club
# Arsenal                 83.00  83.00
# CD Lugo                 87.00  87.00
# Melbourne Victory       81.00  81.00
# Sydney FC               88.00  88.00
# Toronto FC              81.75  81.75
# Vitória                 91.00  91.00
# All                     84.00  84.00
#                   SprintSpeed
# Position                   ST    All
# Club
# Vitória                 91.00  91.00
# Sydney FC               88.00  88.00
# CD Lugo                 87.00  87.00
# All                     84.00  84.00
# Arsenal                 83.00  83.00
# Toronto FC              81.75  81.75
# Melbourne Victory       81.00  81.00
