# %% [markdown]
# Алгоритмы машинного обучения не работают напрямую с временными рядами.
#
# Например,  у нас есть временной ряд, как на одной из этих картинок. Каждый ряд состоит из 300 точек. То есть каждая точка являлась бы отдельной фичей, в результате мы получили бы более чем 300 000 фич на 1 временной ряд, что вычислительно очень сложно и не оптимально.
#
# Поэтому обычно из временных рядов выделяются характерные признаки («фичи»).

# %% [markdown]
# ![m8_18_image1.png](attachment:m8_18_image1.png)

# %% [markdown]
# Данные с термодатчиков при литье автомобильных двигателей. Красные кривые соответствуют литью двигателей с дефектами. Зеленые — без дефектов.
#
# Например, мы хотим обучить алгоритм отличать, какие двигатели будут дефективными только на базе температур с термодатчика. В данном случае мы могли бы использовать выделение фич для решения этой задачи.
#
# Выделение признаков вручную.
#
# Перед применением алгоритмов машинного обучения временной ряд заменяется на набор признаков.
#
# Примеры признаков:
#
# максимальное / минимальное значение,
# среднее, медиана, стандартное отклонение
# первое / последнее значение ряда
# позиция / значение максимума / минимума
# наклон
# др.
# Пример выделения признаков на графике:

# %% [markdown]
# ![m8_18_image2.png](attachment:m8_18_image2.png)

# %% [markdown]
# Автоматизированное выделение признаков при помощи TSFresh
#
# В Python есть сторонний пакет TSFresh:
#
# - выделяет несколько сотен признаков,
# - позволяет выбирать наиболее значимые признаки из всех выделенных.
#
# В следующем примере мы описываем словарь с теми фичами, которые хотим выделить. После того, как описали словарь с фичами, вызываем функцию extract_features(), передаем туда наш датасет, параметры и в результате мы получаем уже новый DataFrame, в котором лежат выделенные признаки.

# %% [markdown]
# ![m8_18_image3.png](attachment:m8_18_image3.png)
