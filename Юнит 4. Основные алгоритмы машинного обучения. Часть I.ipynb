# %% [markdown]
# # Зачем нужен матанализ?
#
# Матанализ - это фундамент, на котором строится оптимизация модели машинного обучения (поиск минимумов и максимумов)

# %% [markdown]
# # Функции

# %% [markdown]
# Определение: Функцией в математике называется правило, по которому можно сопоставить элементы двух множеств.

# %% [markdown]
# Формальное определение: Для любого элемента х из множества Х существует единственный элемент y из множества Y, такой что f(x) = y:

# %% [markdown]
# ![c48890b8c9.jpg](attachment:c48890b8c9.jpg)

# %% [markdown]
# Восклицательный знак в формальном определении функции говорит о том, что такая пара x – y должна быть одна. Это значит, что нельзя одному х поставить в соответствие два разных y. И в то же время двум х — один y: сколько угодно!
#
# x - аргумент функции

# %% [markdown]
# ## Числовые функции

# %% [markdown]
# ![6c8774466f.jpg](attachment:6c8774466f.jpg)

# %% [markdown]
# В этом модуле мы будем рассматривать два вида функций: функции одной переменной и функции многих переменных.
#
# Одна из важный идей анализа состоит в том, чтобы собрать небольшой пул хорошо изученных функций, из которых, как из кирпичей, можно построить любую другую функцию. Весь этот увлекательный конструктор называется элементарными функциями. Построить из таких кирпичей совсем любую функцию не получится, тем не менее элементарных функций довольно много и они закрывают большое количество прикладных задач.

# %% [markdown]
# Если мы хотим собирать сложные функции из простых, нам нужны правила конструирования:

# %% [markdown]
# ![c950edb026.jpg](attachment:c950edb026.jpg)

# %% [markdown]
# ## Композиция
#
# Пусть у нас есть две функции — f и g, f действует из X в Y, а g — из Y в Z. Тогда мы можем сделать правило, по которому элементу из X будет ставиться в соответствие единственный элемент из Z. Это правило назовем h — оно и будет композицией правил g и f

# %% [markdown]
# ![5d5f051887.jpg](attachment:5d5f051887.jpg)

# %% [markdown]
# ## Приращение

# %% [markdown]
# Изменение величин в математике называют приращением. Производная - это и есть приращение.

# %% [markdown]
# ### Функция одной переменной

# %% [markdown]
# Определение:  Числовая функция одной переменной —  это правило соответствия между числами x и y, согласно которому каждому x из области определения Df ставится в соответствие ровно один y из области значений Ef.

# %% [markdown]
# Обозначение:

# %% [markdown]
# ![6bba569eb4.jpg](attachment:6bba569eb4.jpg)

# %% [markdown]
# Функции одной переменной часто изображают графически в декартовой системе координат

# %% [markdown]
# ![233c2a154c.jpg](attachment:233c2a154c.jpg)

# %% [markdown]
# #### Функции одной переменной в python

# %% [markdown]
# Давайте рассмотрим на примере параболы, как можно построить график функции одной переменной в python. Как мы знаем, график параболы имеет вид  y = x**2. Давайте построим её на промежутке [-10,10] с шагом изменения аргумента 0.01.
#
# За визуализацию данных здесь отвечает библиотека matplotlib.pyplot, она реализует удобный интерфейс построения графиков в python. Сам модуль pyplot в основном предназначен для интерактивных графиков и простых случаев программной генерации графиков.
#
# Для создания последовательностей чисел в numpy имеется функция numpy.arange(), аналогичная встроенной в python range(), только вместо списков она возвращает массивы и принимает не только целые значения.

# %%
#  импортируем необходимые библиотеки для работы с массивами чисел и для визуализации
import numpy as np
import matplotlib.pyplot as plt

# х - аргумент в нашей функции. 
# передадим начало и конец числового отрезка нашей функции и шаг аргумента:
x = np.arange(-10, 10.01, 0.01) # массив значений аргумента

# построение графика параболы
plt.plot(x, x**2) 

# включим сетку на графике 
plt.grid(True)

# показать график
plt.show()

# %% [markdown]
# Как мы видим на графике, каждому допустимому значению x соответствует единственное значение y.

# %% [markdown]
# ### Элементарные функции

# %% [markdown]
# Определение:  Элементарные функции — это функции, которые являются суммой, произведением или композицией элементов трех видов: Степенные функции, Тригонометрические функции, Показательные и логарифмические функции

# %% [markdown]
# ![%D0%B7%D0%B0%D0%B2%D0%B0%D0%BD%D1%82%D0%B0%D0%B6%D0%B5%D0%BD%D0%BD%D1%8F.png](attachment:%D0%B7%D0%B0%D0%B2%D0%B0%D0%BD%D1%82%D0%B0%D0%B6%D0%B5%D0%BD%D0%BD%D1%8F.png)

# %% [markdown]
# Элементарные функции можно записать понятной формулой из элементов–кирпичиков. А это значит, что их легко анализировать, зная свойства этих кирпичиков

# %% [markdown]
# Давайте познакомимся поближе с некоторыми полезными функциями.

# %% [markdown]
# **Арктангенс**

# %% [markdown]
# Определение:  В тригонометрии arctg (x) — это угол, тангенс которого равен х.

# %% [markdown]
# То есть arctg (x) — функция обратная tg (x).

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# **Экспонента**

# %% [markdown]
# ![Screenshot_4.png](attachment:Screenshot_4.png)

# %% [markdown]
# ![Screenshot_5.png](attachment:Screenshot_5.png)

# %% [markdown]
# **Экспоненциальное распределение и распределение Пуассона**

# %% [markdown]
# ![Screenshot_6.png](attachment:Screenshot_6.png)

# %% [markdown]
# **Сигмоида**

# %% [markdown]
# ![Screenshot_7.png](attachment:Screenshot_7.png)

# %% [markdown]
# **Натуральный логарифм**

# %% [markdown]
# ![Screenshot_8.png](attachment:Screenshot_8.png)

# %% [markdown]
# **Индикатор**

# %% [markdown]
# ![Screenshot_9.png](attachment:Screenshot_9.png)

# %% [markdown]
# Множеством значений функции y = f(x) на интервале X называют множество всех значений функции, которые она принимает при переборе всех x є X.

# %% [markdown]
# Областью значений функции y = f(x) называется множество всех значений функции, которые она принимает при переборе всех x из области определения x є D(f).

# %% [markdown]
# Область значений функции обозначают как E(f).
#
# Область значений функции и множество значений функции - это не одно и то же. Эти понятия будем считать эквивалентными, если интервал X при нахождении множества значений функции y = f(x) совпадает с областью определения функции.

# %% [markdown]
# Грубо говоря, где область определения – там есть график функции

# %% [markdown]
# Как найти область определения функции? Многие помнят детскую считалку: «камень, ножницы, бумага», и в данном случае её можно смело перефразировать: «корень, дробь и логарифм». Таким образом, если вам на жизненном пути встречается дробь, корень или логарифм, то следует сразу же очень и очень насторожиться! Намного реже встречаются тангенс, котангенс, арксинус, арккосинус, и о них мы тоже поговорим. Но сначала зарисовки из жизни муравьёв:
#
# http://mathprofi.ru/oblast_opredeleniya.html

# %% [markdown]
# **Найдите область определения и область значений функции**

# %% [markdown]
# ![Screenshot_10.png](attachment:Screenshot_10.png)

# %% [markdown]
# ![Screenshot_11.png](attachment:Screenshot_11.png)

# %% [markdown]
# ### Логарифм

# %% [markdown]
# Логарифм по основанию a от аргумента x — это степень, в которую надо возвести число a, чтобы получить число x.
#
# Итак, перед нами степени двойки. Если взять число из нижней строчки, то можно легко найти степень, в которую придется возвести двойку, чтобы получилось это число. Например, чтобы получить 16, надо два возвести в четвертую степень. А чтобы получить 64, надо два возвести в шестую степень. Это видно из таблицы.

# %% [markdown]
# Логарифм по основанию e (e - трансцендентное число, приближенно равное 2.718281828) называется натуральным логарифмом.
#
# Натуральный логарифм числа x обозначается ln(x).
#
# Натуральные логарифмы широко используются в математике, физике и инженерных расчетах

# %%
np.log(3)
# Out:
# 1.0986122886681098

# %%
# Реализовать композицию функций f(g(x))

def f(x):
    e = 2.718281828
    return e**x

def g(x):
    return np.log(x - 9)

def compose(f, g):
    return lambda x: f(g(x))

compose(f, g)(10)
# Out:
# 1.0

# %% [markdown]
# Найти индикаторную (характеристическую) функцию множества. Вот нашел такую формулу:
#
# ![Screenshot_14.png](attachment:Screenshot_14.png)

# %% [markdown]
# ### Производная. Общие понятия

# %% [markdown]
# В прикладных задачах часто нужно посчитать приближённое значение функции в некоторой точке.
#
# Определение:  Производная — есть предел приращений и тангенс угла наклона касательной.
#
# Вебинар: https://lms.skillfactory.ru/courses/course-v1:Skillfactory+DST-WEBINARS+MAY2020/courseware/ddfe610cc40e4e7b9b3c7969711c701e/4bfb025f4d4445b59efbfe3c40efb0ed/1?activate_block_id=block-v1%3ASkillfactory%2BDST-WEBINARS%2BMAY2020%2Btype%40vertical%2Bblock%40deb949b5bc514f52833d3eb1c11518f4

# %% [markdown]
# ### Линеаризация

# %% [markdown]
# Определение: Задача о приближении, с помощью которой мы только что ввели понятие производной, называется линеаризацией

# %% [markdown]
# На идее линеаризации основываются marginal effects в нелинейных регрессиях.

# %% [markdown]
# Здесь вы можете сделать паузу и познакомиться с таблицей производных элементарных функций: http://portal.tpu.ru:7777/SHARED/k/KONVAL/Sites/Russian_sites/Calc1-ru/4/18.htm

# %%
np.sqrt(8)
# Out:
# 2.8284271247461903

# %% [markdown]
# ### Производная. Монотонность. Дифференцирование

# %% [markdown]
# Из линеаризации следует еще одна интерпретация производной. Сравним поведение трёх функций

# %% [markdown]
# ![Screenshot_15.png](attachment:Screenshot_15.png)

# %% [markdown]
# #### Правила дифференцирования

# %% [markdown]
# ![Screenshot_16.png](attachment:Screenshot_16.png)

# %% [markdown]
# Как любой инструмент, производная имеет свои ограничения. У некоторых функций производная не существует.

# %% [markdown]
# ![Screenshot_17.png](attachment:Screenshot_17.png)

# %% [markdown]
# ![Screenshot_18.png](attachment:Screenshot_18.png)

# %% [markdown]
# Формула для решения квадратных уравнений: ax**2 + bx + c
#
# http://mathprofi.ru/goryachie_formuly.pdf

# %% [markdown]
# ### Функция многих переменных

# %% [markdown]
# На практике часто нужно исследовать функцию нескольких (или многих) переменных. Такая функция получает на вход несколько чисел (аргументов), а возвращает одно значение

# %% [markdown]
# #### Евклидово расстояние

# %% [markdown]
# ![Screenshot_19.png](attachment:Screenshot_19.png)

# %% [markdown]
# ### Квадрат расстояния

# %% [markdown]
# Как вы помните, у квадратного корня есть проблемы с производной, поэтому для удобства в анализе часто пользуются квадратом расстояния:

# %% [markdown]
# ![Screenshot_20.png](attachment:Screenshot_20.png)

# %% [markdown]
# ### Loss function

# %% [markdown]
# ![Screenshot_21.png](attachment:Screenshot_21.png)

# %% [markdown]
# ### Сигмоида

# %% [markdown]
# ![Screenshot_22.png](attachment:Screenshot_22.png)

# %%
def t3_7_1(x,y):   
    return np.sqrt(x**2 + y**2)

dist_a_b = t3_7_1(2,1)
dist_a_b
# Out:
# 2.23606797749979

# %%
e = np.e

def t3_7_2():
    result = e**(-2)
    return result
    
result_t3_7_2 = 1 / (1 + t3_7_2())
result_t3_7_2
# Out:
# 0.8807970779778823

# %% [markdown]
# ### Частные производные

# %% [markdown]
# ### Оптимизация. Оптимизация на практике (Python)

# %% [markdown]
# Оптимизация - сердце Data Science

# %% [markdown]
# Общий интерфейс для решения задач как условной, так и безусловной оптимизации в пакете scipy.optimize предоставляется функцией minimize(). Однако известно, что универсального способа для решения всех задач не существует, поэтому выбор подходящего метода как всегда ложится на плечи исследователя.
#
# Подходящий алгоритм оптимизации задаётся с помощью аргумента функции minimize(..., method="").
#
# Функция minimize из пакета scipy.optimize предоставляет общий интерфейс для решения задач условной и безусловной минимизации скалярных функций нескольких переменных. Чтобы продемонстрировать её работу, нам понадобится подходящая функция нескольких переменных, которую мы будем минимизировать.
#
# Для этих целей прекрасно подойдет функция Розенброка от N переменных, которая имеет вид:

# %% [markdown]
# ![Screenshot_23.png](attachment:Screenshot_23.png)

# %% [markdown]
# Несмотря на то, что функция Розенброка и её матрицы Якоби и Гессе (первой и второй производной соответственно) уже определены в пакете scipy.optimize, определим её самостоятельно.

# %%
import numpy as np

def rosen(x):
# Функция Розенброка
    return np.sum(100.0*(x[1:]-x[:-1]**2.0)**2.0 + (1-x[:-1])**2.0, axis=0)

# %% [markdown]
# Для наглядности отрисуем в 3D значения функции Розенброка от двух переменных.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# Настраиваем 3D график
fig = plt.figure(figsize=[15, 10])
ax = fig.gca(projection='3d')

# Задаем угол обзора
ax.view_init(45, 30)

# Создаем данные для графика
X = np.arange(-2, 2, 0.1)
Y = np.arange(-1, 3, 0.1)
X, Y = np.meshgrid(X, Y)
Z = rosen(np.array([X,Y]))

# Рисуем поверхность
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.show()

# %% [markdown]
# #### Метод Пауэлла

# %% [markdown]
# Алгоритмом оптимизации, в котором вычисляются только значения функций, является метод Пауэлла. Чтобы использовать его, нужно установить method = 'powell' в функции minim.

# %%
from scipy.optimize import minimize 
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(rosen, x0, method='powell',
    options={'xtol': 1e-8, 'disp': True})
print(res.x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 1622
# [1. 1. 1. 1. 1.]

# %% [markdown]
# #### Симплекс-метод Нелдера-Мида (Nelder-Mead)

# %% [markdown]
# Пусть имеется начальная точка x0 в 5-мерном пространстве. Найдём ближайшую к ней точку минимума функции Розенброка с помощью алгоритма симплекса Nelder-Mead (алгоритм указан в качестве значения параметра method):

# %%
from scipy.optimize import minimize
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(rosen, x0, method='nelder-mead',
    options={'xtol': 1e-8, 'disp': True})
print(res.x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 339
#          Function evaluations: 571
# [1. 1. 1. 1. 1.]

# %% [markdown]
# Симплекс-метод является самым простым способом свести к минимуму явно определенную и довольно гладкую функцию. Он не требует вычисления производных функции, достаточно задать только её значения. Метод Нелдера-Мида является хорошим выбором для простых задач минимизации. Однако, поскольку он не использует оценки градиента, для поиска минимума может потребоваться больше времени.

# %% [markdown]
# Для более полного понимания организации методов оптимизации в Python рекомендуем прочесть статью: https://habr.com/ru/company/ods/blog/448054/
