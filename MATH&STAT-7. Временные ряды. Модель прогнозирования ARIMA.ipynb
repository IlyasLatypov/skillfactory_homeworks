# %% [markdown]
# Что же делать, если ряд нестационарный?
#
# ДИФФЕРЕНЦИРОВАНИЕ РЯДА

# %% [markdown]
# ![4c7efc5d44.jpg](attachment:4c7efc5d44.jpg)

# %% [markdown]
# ![abc2a73b24.jpg](attachment:abc2a73b24.jpg)

# %% [markdown]
# ![cf118c7422.jpg](attachment:cf118c7422.jpg)
