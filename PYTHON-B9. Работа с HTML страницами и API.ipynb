# %% [markdown]
# # Введение

# %% [markdown]
# ## Web-запросы

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Начнем с основ автоматизированных веб-запросов на примере задачи получения курсов валют. Курс валют – полезная и регулярно обновляемая информация, но залезать каждый раз на сайт за ней – трудоёмко. Значит, вам нужен скрипт, который будет в удобном виде выгружать информацию по курсам валют.
#
# Будем использовать сервис cbr-xml-daily.ru. Он возвращает информацию о курсах валют в структурированном формате JSON, и в дальнейшем мы расширим этот подход на произвольные html страницы.
#
# Итак, нам необходима функция, возвращающая курс заданной валюты в двух форматах:
#
# 1. Только значение курса валюты.
#
# 2. Полную информацию о валюте: курс, название, номинал и другие характеристики.

# %% [markdown]
# ### Протокол HTTP

# %% [markdown]
# Мы будем работать с веб-запросами, и для начала полезно будет вспомнить, как работает интернет.
#
# Один компьютер (клиент) отправляет запрос в определённом формате другому компьютеру (серверу) и получает в ответ текст и мультимедийные файлы (картинки, видео). Обычно это происходит по протоколу http, который формализует это общение.

# %% [markdown]
# Запрос в http состоит из нескольких частей:
#
# - адрес, по которому мы обращаемся (это то, что вы вводите в строке браузера, например, www.google.com);<br />
# - техническая информация, вроде кукисов и метода запроса;<br />
# - иногда ещё дополнительные данные, например, если вы сами загружаете картинку.
#
# Ответ содержит:
#
# - статус ответа: 200 для успешного ответа; 404, если адрес не найден и т.д.; полный список http статусов можно посмотреть здесь ;<br />
# - текст в запрошенном формате (html, xml, json...) или мультимедийные файлы; <br />
# - техническую информацию.
#
# В протоколе HTTP запросы могут делаться с помощью одного из так называемых методов. Самые популярные — это GET и POST .
#
# Метод GET просто получает текстовую информацию или мультимедийный файл по адресу. Вы как бы говорите: "Хочу получить страницу по адресу www.google.com" , и сервер вам отвечает: "200, ок, держи вот html". Это самый базовый метод.
#
# Метод POST служит для отправки форм; помимо адреса он может "заворачивать" в себя дополнительные данные, вроде полей формы или картинок. Вы как бы "заворачиваете" посылку и отдаёте её почтальону.
#
# Обычно всю эту работу делает браузер, но мы можем делать эти же запросы из кода. Мы могли бы даже написать свой маленький браузер на python, но в этом модуле мы сосредоточимся на автоматическом сборе информации.

# %% [markdown]
# ## Библиотека requests

# %% [markdown]
# Сначала разберемся, как получить информацию с внешнего сервиса. В стандартной библиотеке есть модуль urllib2, который может справиться с этой задачей. Однако большинство разработчиков используют стороннюю библиотеку requests, потому что в ней лучше реализованы большинство методов и код получается проще. Перед началом работы библиотеку потребуется установить с помощью вашего пакетного менеджера, например, с помощью следующей команды в консоли.

# %%
# python -m pip install requests

# %% [markdown]
# Далее мы импортируем библиотеку и отправим запрос к сервису с помощью метода GET к сервису с курсами валют:

# %%
import requests  
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа, который содержит всю нужную нам информацию. По умолчанию на экран выводится HTTP-код ответа 200. Это означает, что запрос был корректным, и сервер отдал нам нужную информацию.
#
# Код ответа в виде числа можно получить с помощью метода status_code:

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### Читаем результат

# %% [markdown]
# Мы сделали запрос и получили ответ. Давайте теперь посмотрим, как считывать текст.
#
# Адрес, по которому мы обращались, возвращает результат в json формате. Эти данные уже лежат в атрибуте text в полученном ответе response:

# %%
print(response.text)
# Out:
# {
#     "Date": "2020-08-22T11:30:00+03:00",
#     "PreviousDate": "2020-08-21T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2020\/08\/21\/daily_json.js",
#     "Timestamp": "2020-08-23T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 53.2185,
#             "Previous": 52.7242
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 43.6138,
#             "Previous": 43.4203
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 97.7822,
#             "Previous": 96.4631
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 15.2878,
#             "Previous": 15.2043
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.3407,
#             "Previous": 29.6269
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 44.7679,
#             "Previous": 44.5585
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.3343,
#             "Previous": 13.2734
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 24.9692,
#             "Previous": 24.8689
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 95.6091,
#             "Previous": 95.1861
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 11.7611,
#             "Previous": 11.7067
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 74.0999,
#             "Previous": 73.7711
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 87.7343,
#             "Previous": 87.4261
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 98.9893,
#             "Previous": 98.3228
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.6563,
#             "Previous": 17.5968
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 56.1363,
#             "Previous": 55.752
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 95.2885,
#             "Previous": 94.6997
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 10.7174,
#             "Previous": 10.657
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 44.7463,
#             "Previous": 44.5612
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 82.8497,
#             "Previous": 82.2897
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 19.9418,
#             "Previous": 19.8187
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 18.0899,
#             "Previous": 18.0096
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 104.6735,
#             "Previous": 104.6251
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 54.1468,
#             "Previous": 53.8279
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 71.8196,
#             "Previous": 71.5009
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 1,
#             "Name": "Турецкая лира",
#             "Value": 10.2188,
#             "Previous": 10.0784
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 21.2017,
#             "Previous": 21.1076
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 72.1799,
#             "Previous": 71.8946
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 27.0339,
#             "Previous": 26.8088
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 33.6054,
#             "Previous": 33.4093
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 84.6846,
#             "Previous": 84.3098
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 81.4195,
#             "Previous": 80.6506
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 42.8487,
#             "Previous": 42.5738
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 62.3716,
#             "Previous": 62.0121
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 70.2302,
#             "Previous": 69.5593
#         }
#     }
# }

# %% [markdown]
# Вы можете посмотреть на полный текст, повторив запрос или на этой странице в вашем браузере: https://www.cbr-xml-daily.ru/daily_json.js
#
# Сейчас текст хранится просто в строковой переменной. Далее мы можем превратить эту строку в словарь. Сделать это можно с помощью JSON-парсера python, либо воспользовавшись методом json, который уже встроен в объект ответа response:

# %%
currencies = response.json()  
print(currencies)
# Out:
# {'Date': '2020-08-22T11:30:00+03:00', 'PreviousDate': '2020-08-21T11:30:00+03:00', 'PreviousURL': '//www.cbr-xml-daily.ru/archive/2020/08/21/daily_json.js', 'Timestamp': '2020-08-23T23:00:00+03:00', 'Valute': {'AUD': {'ID': 'R01010', 'NumCode': '036', 'CharCode': 'AUD', 'Nominal': 1, 'Name': 'Австралийский доллар', 'Value': 53.2185, 'Previous': 52.7242}, 'AZN': {'ID': 'R01020A', 'NumCode': '944', 'CharCode': 'AZN', 'Nominal': 1, 'Name': 'Азербайджанский манат', 'Value': 43.6138, 'Previous': 43.4203}, 'GBP': {'ID': 'R01035', 'NumCode': '826', 'CharCode': 'GBP', 'Nominal': 1, 'Name': 'Фунт стерлингов Соединенного королевства', 'Value': 97.7822, 'Previous': 96.4631}, 'AMD': {'ID': 'R01060', 'NumCode': '051', 'CharCode': 'AMD', 'Nominal': 100, 'Name': 'Армянских драмов', 'Value': 15.2878, 'Previous': 15.2043}, 'BYN': {'ID': 'R01090B', 'NumCode': '933', 'CharCode': 'BYN', 'Nominal': 1, 'Name': 'Белорусский рубль', 'Value': 29.3407, 'Previous': 29.6269}, 'BGN': {'ID': 'R01100', 'NumCode': '975', 'CharCode': 'BGN', 'Nominal': 1, 'Name': 'Болгарский лев', 'Value': 44.7679, 'Previous': 44.5585}, 'BRL': {'ID': 'R01115', 'NumCode': '986', 'CharCode': 'BRL', 'Nominal': 1, 'Name': 'Бразильский реал', 'Value': 13.3343, 'Previous': 13.2734}, 'HUF': {'ID': 'R01135', 'NumCode': '348', 'CharCode': 'HUF', 'Nominal': 100, 'Name': 'Венгерских форинтов', 'Value': 24.9692, 'Previous': 24.8689}, 'HKD': {'ID': 'R01200', 'NumCode': '344', 'CharCode': 'HKD', 'Nominal': 10, 'Name': 'Гонконгских долларов', 'Value': 95.6091, 'Previous': 95.1861}, 'DKK': {'ID': 'R01215', 'NumCode': '208', 'CharCode': 'DKK', 'Nominal': 1, 'Name': 'Датская крона', 'Value': 11.7611, 'Previous': 11.7067}, 'USD': {'ID': 'R01235', 'NumCode': '840', 'CharCode': 'USD', 'Nominal': 1, 'Name': 'Доллар США', 'Value': 74.0999, 'Previous': 73.7711}, 'EUR': {'ID': 'R01239', 'NumCode': '978', 'CharCode': 'EUR', 'Nominal': 1, 'Name': 'Евро', 'Value': 87.7343, 'Previous': 87.4261}, 'INR': {'ID': 'R01270', 'NumCode': '356', 'CharCode': 'INR', 'Nominal': 100, 'Name': 'Индийских рупий', 'Value': 98.9893, 'Previous': 98.3228}, 'KZT': {'ID': 'R01335', 'NumCode': '398', 'CharCode': 'KZT', 'Nominal': 100, 'Name': 'Казахстанских тенге', 'Value': 17.6563, 'Previous': 17.5968}, 'CAD': {'ID': 'R01350', 'NumCode': '124', 'CharCode': 'CAD', 'Nominal': 1, 'Name': 'Канадский доллар', 'Value': 56.1363, 'Previous': 55.752}, 'KGS': {'ID': 'R01370', 'NumCode': '417', 'CharCode': 'KGS', 'Nominal': 100, 'Name': 'Киргизских сомов', 'Value': 95.2885, 'Previous': 94.6997}, 'CNY': {'ID': 'R01375', 'NumCode': '156', 'CharCode': 'CNY', 'Nominal': 1, 'Name': 'Китайский юань', 'Value': 10.7174, 'Previous': 10.657}, 'MDL': {'ID': 'R01500', 'NumCode': '498', 'CharCode': 'MDL', 'Nominal': 10, 'Name': 'Молдавских леев', 'Value': 44.7463, 'Previous': 44.5612}, 'NOK': {'ID': 'R01535', 'NumCode': '578', 'CharCode': 'NOK', 'Nominal': 10, 'Name': 'Норвежских крон', 'Value': 82.8497, 'Previous': 82.2897}, 'PLN': {'ID': 'R01565', 'NumCode': '985', 'CharCode': 'PLN', 'Nominal': 1, 'Name': 'Польский злотый', 'Value': 19.9418, 'Previous': 19.8187}, 'RON': {'ID': 'R01585F', 'NumCode': '946', 'CharCode': 'RON', 'Nominal': 1, 'Name': 'Румынский лей', 'Value': 18.0899, 'Previous': 18.0096}, 'XDR': {'ID': 'R01589', 'NumCode': '960', 'CharCode': 'XDR', 'Nominal': 1, 'Name': 'СДР (специальные права заимствования)', 'Value': 104.6735, 'Previous': 104.6251}, 'SGD': {'ID': 'R01625', 'NumCode': '702', 'CharCode': 'SGD', 'Nominal': 1, 'Name': 'Сингапурский доллар', 'Value': 54.1468, 'Previous': 53.8279}, 'TJS': {'ID': 'R01670', 'NumCode': '972', 'CharCode': 'TJS', 'Nominal': 10, 'Name': 'Таджикских сомони', 'Value': 71.8196, 'Previous': 71.5009}, 'TRY': {'ID': 'R01700J', 'NumCode': '949', 'CharCode': 'TRY', 'Nominal': 1, 'Name': 'Турецкая лира', 'Value': 10.2188, 'Previous': 10.0784}, 'TMT': {'ID': 'R01710A', 'NumCode': '934', 'CharCode': 'TMT', 'Nominal': 1, 'Name': 'Новый туркменский манат', 'Value': 21.2017, 'Previous': 21.1076}, 'UZS': {'ID' ...

# %% [markdown]
# Теперь данные лежат в словаре, и мы можем легко получать необходимые нам значения:

# %%
currencies['Valute']['UAH']
# Out:
# {'ID': 'R01720',
#  'NumCode': '980',
#  'CharCode': 'UAH',
#  'Nominal': 10,
#  'Name': 'Украинских гривен',
#  'Value': 27.0339,
#  'Previous': 26.8088}

# %% [markdown]
# Данные получены, и задание выполнено.

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ### Оформляем функцию

# %% [markdown]
# В завершение давайте оформим наши вычисления в отдельную функцию, которой будет удобно пользоваться. На вход она должна принимать два параметра:
#
# 1. Название валюты currency. Например, 'EUR' или 'USD'.
#
# 2. Формат ответа format. При значении 'full' будем отдавать все, что знаем о валюте. А при значении format = 'value' только значение ключа 'Value', т. е. курс: 69.0286.
#
# Оформим наши требования в коде:

# %%
def exchange_rates(currency, format='full'):    
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']    
    data = response[currency]     
    if format == 'full':    
        return data      
    elif format == 'value':    
        return data['Value']

# %% [markdown]
# #### Задание 1
#
# Напишите функцию currency_name, которая по ID валюты возвращает ее название на русском языке.

# %%
def currency_name(id):
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']   
    data = response    
  
    for currency in data:

        if data[currency]['ID'] == id:
            return data[currency]['Name']
        

    


currency_name('R01700J')
# Out:
# 'Турецкая лира'

# %% [markdown]
# #### HTML-страницы

# %% [markdown]
# ##### Постановка задачи

# %% [markdown]
# Довольно часто приходится добывать информацию не из удобно форматированного json-файла, а прямо с HTML-страниц. Получить содержимое страницы в большинстве случаев несложно, труднее извлечь из HTML-кода нужную информацию. В качестве примера мы рассмотрим страницу новости, из которой будем доставать полезную информацию: 1) заголовок страницы; 2) дату публикации; 3) текст публикации; 4) ссылки на странице.

# %% [markdown]
# Получаем данные
#
# Получить html страницу можно так же, как мы получали до этого json: используем библиотеку requests и метод GET:

# %%
import requests  
  
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
  
response = requests.get(url)  
  
# Убедимся, что мы успешно получили ответ     
print(response.status_code)    
# => 200   
  
# Выведем полученные данные    
print(response.text)
# Out:
# 200
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#
#     <link rel="canonical" href="https://nplus1.ru/news/2019/06/04/slothbot" />
#
#         <title>Робота-ленивца научили лазать по паутине из тросов</title>
#
#     	    <meta itemprop="datePublished" content="2019-06-04"/>
#
# 	    <meta name="mediator_author" content="Григорий Копиев"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2019/06/04/slothbot/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Он сам добывает энергию с помощью солнечных панелей" />
#
#         <meta name="author" content="Григорий Копиев" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2019/06/04/slothbot" />
#         <meta property="og:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#         <meta name="twitter:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1594129211">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1567698280">
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json"> { "@context": "http://schema.org", "@type": "WebSite", "url": "https://nplus1.ru/news/2019/06/04/slothbot", "name": "Робота-ленивца научили лазать по паутине из тросов", "description": "Он сам добывает энергию с помощью солнечных панелей", "image": "https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg", "publisher": { "@type": "Organization", "name": "N+1", "logo": { "@type":"ImageObject", "url": "https://nplus1.ru/i/logo-alt.png" }, "sameAs": [ "https://www.facebook.com/nplusone", "https://twitter.com/nplusodin", "https://vk.com/nplusone", "https://ok.ru/nplus1", "https://soundcloud.com/nplus_1", "https://t.me/nplusone" ] }, "potentialAction":{ "@type":"SearchAction", "target":"https://nplus1.ru/search?q={search_term_string}", "query-input":"required name=search_term_string" } } </script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" class="_inner  ">
#
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: Верхняя перетяжка 100%-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15000335664353901"></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
# </script>
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#                 </li>
#                             <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="explainatorium">
#             <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#         </li>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2020/08/18/sma-drug-prices" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/18/sma-drug-prices" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Укол ценой два миллиона: что происходит с лекарствами от спинальной мышечной атрофии</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/13/the-story-of-an-unregulated-man" class="container-link">
#                     <div class="heading"><span>Премия &laquo;Просветитель&raquo;</span></div>
#                     <div class="link"><span>Василий Авченко, Алексей Коровашко &laquo;Олег Куваев: повесть о нерегламентированном человеке&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/12/how-a-city-works" class="container-link">
#                     <div class="heading"><span>Премия &laquo;Просветитель&raquo;</span></div>
#                     <div class="link"><span>Григорий Ревзин &laquo;Как устроен город: 36 эссе по философии урбанистики&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/11/read-the-manual" class="container-link">
#                     <div class="heading"><span>Коронавирусные хроники</span></div>
#                     <div class="link"><span>Первый пошел: читаем инструкцию к российской вакцине от COVID-19</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/11/the-age-of-decay" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Артем Рондарев &laquo;Эпоха распада. Грандиозная история музыки в XX веке&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/10/adventures-in-memory" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Хильде Эстбю, Ильва Эстбю &laquo;Это мой конек: Наука запоминания и забывания&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/07/hiroshima" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Джон Херси &laquo;Хиросима&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/06/3comma5-eleven" class="container-link">
#                     <div class="heading"><span>Три с половиной</span></div>
#                     <div class="link"><span>Беспилотный стендап, жужжание комаров и шкала Кинси</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2020/08/06/diptera" class="container-link">
#                     <div class="heading"><span>Премия &laquo;Просветитель&raquo;</span></div>
#                     <div class="link"><span>Никита Вихрев &laquo;Рассказы о двукрылых с обзором основных семейств отряда&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2020/08/20/generation-y" class="container-link active">
#         	        	<div class="heading"><span>Премия &laquo;Просветитель&raquo;</span></div>
#             	    	<div class="link"><span>Вадим Радаев &laquo;Миллениалы: Как меняется российское общество&raquo;</span></div>
# 		            </a>
# 	                                </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="20774" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>
#                                             </p>
#         <p class="table">
#             <a href="/news/2019/06/04">
#                 <time itemprop="datePublished" content="2019-06-04" data-unix="1559662033">
#                     <span>18:27</span>
#                     <span>04 Июнь 2019</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/2.2">
#                 <span>Сложность</span>
#                 <span class="difficult-value">2.2</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Григорий Копиев';
#         _dlData.custom_difficult = '2.2';
#         _dlData.custom_rubric.push('Роботы и дроны');
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Робота-ленивца научили лазать по паутине из тросов</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg"/>
#                                                                 <figcaption>
#                                     <p class="title"></p>
#                                     <p class="credits">Allison Carter, Georgia Tech</p>
#                                 </figcaption>
#                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Американские инженеры разработали робота-ленивца, способного лазать по&nbsp;тросам и&nbsp;перемещаться с&nbsp;одного троса на&nbsp;другой. Благодаря относительно малому потреблению энергии и&nbsp;использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы <a href="https://ieeexplore.ieee.org/document/8642808" target="_blank" rel="nofollow">статьи</a>, представленной на&nbsp;конференции ICRA 2019.</p>
# <p>Создание роботов, способных лазать по&nbsp;тросам&nbsp;— важная технологическая задача, наработки из&nbsp;которой потенциально применимы во&nbsp;многих областях. К&nbsp;примеру, в&nbsp;2016 году в&nbsp;России <a href="https://nplus1.ru/news/2016/09/28/robot" target="_blank">создали</a> робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на&nbsp;грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и&nbsp;осматривает&nbsp;их. Кроме того, потенциально таких роботов можно применять для исследований в&nbsp;густых лесах, в&nbsp;которых ветки соседних деревьев соприкасаются.</p>
# <p>Инженеры из&nbsp;Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и&nbsp;решили создать энергоэффективного робота, на&nbsp;основе которого можно было&nbsp;бы создать робота, способного лазать по&nbsp;веткам. Робот состоит из&nbsp;двух частей и передвигается благодаря колесу в&nbsp;каждой части, соприкасающемуся с&nbsp;тросом.<br></p>
# <p><iframe frameborder="0" src="//www.youtube.com/embed/Sx-WL6BIK3s" width="620" height="349" allowfullscreen="true" class="embed-responsive-item"></iframe><br></p>
# <p>Кроме того, в&nbsp;каждой части робота есть две полноценные шестерни и&nbsp;две связанные с&nbsp;ними, но&nbsp;с&nbsp;вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не&nbsp;мог выйти за&nbsp;ее&nbsp;пределы. Если&nbsp;же роботу необходимо перейти на&nbsp;смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в&nbsp;петле, соединяющей две части.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Компоненты одной из двух частей робота</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а&nbsp;также две солнечные панели, располагающиеся по&nbsp;бокам одной из&nbsp;частей. Разработчики отмечают, что благодаря применению колес для движения по&nbsp;тросам, а&nbsp;также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по&nbsp;тросам.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Механизм блокировки троса</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по&nbsp;тросам. Пользователь может указать точку, за&nbsp;которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до&nbsp;наиболее близкой к заданной точке наблюдательной позиции.</p>
# <p>Ранее инженеры из&nbsp;Технологического института Джорджии <a href="https://nplus1.ru/news/2017/04/13/tarzan" target="_blank" title="Link: https://nplus1.ru/news/2017/04/13/tarzan">создали</a> другого робота-ленивца для работы на&nbsp;тросе. Он&nbsp;так&nbsp;же состоит из&nbsp;двух частей, но&nbsp;имеет совершенно другую конструкцию и&nbsp;принцип работы. Он&nbsp;способен зацепляться концом одной части за&nbsp;трос и&nbsp;раскачивать другую, чтобы затем зацепиться&nbsp;ей. После этого он&nbsp;может отпустить первую часть и&nbsp;снова начать раскачиваться для того, чтобы двигаться дальше.<br></p>
# <p><i>Григорий Копиев</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                 <meter class="top"></meter>
#                                         <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/24/humanly-traversable-wormholes" data-id="26163" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2020/08/22/0a0f5324935bfc9614357b7b9d115eea.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2020-08-24">10:06</span>
#                         </div>
#                         <h3>Крупные устья кротовых нор позволят человеку пережить приливные силы</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/24/tempest" data-id="26167" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-08-24">09:34</span>
#                 </div>
#
#                                     <h3>Британцы испытали модель истребителя шестого поколения в аэродинамической трубе</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/22/hubble-neowise" data-id="26165" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-08-22">22 августа</span>
#                 </div>
#
#                                     <h3>&laquo;Хаббл&raquo; рассмотрел кому кометы NEOWISE</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/22/al-amal-correction-trajectory" data-id="26160" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-08-22">22 августа</span>
#                 </div>
#
#                                     <h3>Арабская марсианская станция совершила первый маневр коррекции траектории</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/22/balanophora-yakushimensis" data-id="26164" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2020-08-22">22 августа</span>
#                 </div>
#
#                                     <h3>Синехвостки и дрозды расселили паразитическое растение по островам Рюкю</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/21/heart-organoids" data-id="26153" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/08/21/f740dd6efe8a97870226213bb4dfc832.gif)" class="ill"></div>
#
#
#
#                                     <h3>Биологи вырастили маленькие человеческие сердца из стволовых клеток</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/21/stop-robot-abuse" data-id="26143" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/08/21/16fc64302d15d6b30ed873633c06b4b2.gif)" class="ill"></div>
#
#
#
#                                     <h3>Грустные роботы-свидетели побудили людей заступиться за обиженного робота</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2020/08/21/lunar-mock-up" data-id="26156" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2020/08/21/5701dd5d1bf06f6da105d8bbae5822a9.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Blue Origin представила полноразмерный макет лунного модуля</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2020/08/20/185d9c15d1d3e828357ed08eac658f22.jpg" style=background-image:url(https://nplus1.ru/images/2020/08/20/f4e69d01fb41d651404bda229a9ba0f0.jpg)>
#
#     <a href="/material/2020/08/21/on-aye-ban" data-id="26144" >
#         <div class="caption">
#                                                                                     <h3>Чей уклад запретили</h3>
#                     <p class="subtitle">Суд признал экстремистским &laquo;движение АУЕ&raquo; &mdash; что о нем знают антропологи? И существует ли оно?</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/anthropology">Антропология</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="9EgfcZYdiJsrU0I7EZNFEsVFNzHsSy91yphptmdh">
#         <input type="hidden" name="id_news" value="20774">
#         <input type="hidden" name="id_author" value="102">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="9EgfcZYdiJsrU0I7EZNFEsVFNzHsSy91yphptmdh">
#         <input type="hidden" name="id_news" value="20774">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/18/kerrcats">Физики предложили кодировать кубиты котами Шредингера</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/19/josephson-effect-in-time-crystals">Физики впервые заставили временные кристаллы провзаимодействовать</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/19/photon-exciton">Фотоны связали электроны и дырки в полупроводнике</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/08/20/demonology">Работай, черт</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/24/humanly-traversable-wormholes">Крупные устья кротовых нор позволят человеку пережить приливные силы</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/17/hello-cybersecure-world">Флаги наших спецов</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2020/08/19/y-trouble">Полураспад Адама</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/19/nanouranium">Магнетит помог урану образовать оксидные нанокристаллы</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2020/08/20/bacterial-pomp">Биологи уличили анаэробные бактерии в клеточном дыхании с помощью Rnf-насоса</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">4.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/blog/2020/08/18/sma-drug-prices">Укол ценой два миллиона: что происходит с лекарствами от спинальной мышечной атрофии</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2020 N+1 Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
# <script type="text/javascript" async src="https://relap.io/api/v6/head.js?token=sTVMyshMYp9i7-rv"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1592278962"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Мы получили большую строку с текстом в формате html, который используется для визуальной разметки. Это позволяет делать информацию более наглядной для людей, но в отличие от json, мы не можем просто преобразовать его напрямую в словарь. Далее мы посмотрим, как извлекать информацию из подобных страниц

# %% [markdown]
# ## Библиотека BeautifulSoup

# %% [markdown]
# Для поиска данных на странице воспользуемся библиотекой BeautifulSoup. Она позволяет по названию тэгов и их атрибутов получать содержащийся в них текст.
#
# Она не является частью стандартной библиотеки, поэтому для начала её нужно установить с помощью пакетного менеджера, например, введя в консоли:

# %%
# pip install beautifulsoup4

# %% [markdown]
# Теперь мы можем получать данные из страницы. Давайте получим title (это строка, отображающая в браузерах на закладках)

# %%
# Импортируем наши библиотеки    
from bs4 import BeautifulSoup    
import requests    
    
# Получаем данные, как и ранее    
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
response = requests.get(url)    
    
# Теперь создадим объект BeautifulSoup, указывая html парсер    
page = BeautifulSoup(response.text, 'html.parser')

# Всё готово, чтобы получать данные из страницы    
# Для начала получим title, отображающийся на закладках браузера    
print(page.title)  
# => <title>Робота-ленивца научили лазать по паутине из тросов</title>  
    
# Мы получили тэг. Чтобы достать из него текст, вызовем атрибут text    
page.title.text    
# => 'Робота-ленивца научили лазать по паутине из тросов'
# Out:
# <title>Робота-ленивца научили лазать по паутине из тросов</title>
# 'Робота-ленивца научили лазать по паутине из тросов'

# %% [markdown]
# ### Данные со страницы

# %% [markdown]
# #### Читаем заголовок

# %% [markdown]
# Мы получили данные из title, но как нам забрать текст с самой страницы? Мы можем сделать это, запросив содержимое определённых тэгов.
#
# Пусть мы знаем, что заголовок статьи находится в тэге h1. Тогда мы можем получить его текст с помощью метода find

# %%
print(page.find('h1').text)
# Out:
# Робота-ленивца научили лазать по паутине из тросов

# %% [markdown]
# Как узнать, какой именно тэг нужен? Проще всего это сделать с помощью "инструментов разработчика", которые есть во всех современных браузерах.

# %%
print(page.find('time').text)
# Out:
# 18:27
# 04 Июнь 2019

# %% [markdown]
# #### Задание 2 - Автоматический сбор заголовков
#
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на википедии

# %%
def wiki_header(url):
    
    # Получаем данные, как и ранее    
    response = requests.get(url)    

    # Теперь создадим объект BeautifulSoup, указывая html парсер    
    page = BeautifulSoup(response.text, 'html.parser')

    # Теперь вернем заголовок
    return page.find('h1').text



wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %% [markdown]
# #### Больше данных

# %% [markdown]
# Мы рассмотрели базовый поиск конкретного элемента. Могут встречаться другие вариации:
#
# - когда нам нужно получить много похожих элементов;
# - когда тэг атрибута неуникальный, тогда нам нужно использовать атрибуты (id, class), либо использовать вложенность.
#
# Посмотрим на практике, что делать в случае, когда тэг элемента неуникальный. Пусть мы хотим получить сам текст статьи. Мы видим, что он находится в тэге div

# %% [markdown]
# Тэги div очень распространённые, их много на странице. Если мы просто используем find, то получим первый попавшийся, но это не то, что нам надо.

# %% [markdown]
# Тут мы можем заметить, что у искомого текста есть свой класс GeneralMaterial-body. Воспользуемся этим:  в метод find можно передать аргумент class_

# %%
print(page.find('div', class_='body').text)
# Out:
# Allison Carter, Georgia Tech
#
#
#
#
#
# Американские инженеры разработали робота-ленивца, способного лазать по тросам и перемещаться с одного троса на другой. Благодаря относительно малому потреблению энергии и использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы статьи, представленной на конференции ICRA 2019.
# Создание роботов, способных лазать по тросам — важная технологическая задача, наработки из которой потенциально применимы во многих областях. К примеру, в 2016 году в России создали робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и осматривает их. Кроме того, потенциально таких роботов можно применять для исследований в густых лесах, в которых ветки соседних деревьев соприкасаются.
# Инженеры из Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и решили создать энергоэффективного робота, на основе которого можно было бы создать робота, способного лазать по веткам. Робот состоит из двух частей и передвигается благодаря колесу в каждой части, соприкасающемуся с тросом.
#
# Кроме того, в каждой части робота есть две полноценные шестерни и две связанные с ними, но с вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не мог выйти за ее пределы. Если же роботу необходимо перейти на смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в петле, соединяющей две части.
#
#
#
#
#
#
#
#
#
# Компоненты одной из двух частей робота
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а также две солнечные панели, располагающиеся по бокам одной из частей. Разработчики отмечают, что благодаря применению колес для движения по тросам, а также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по тросам.
#
#
#
#
#
#
#
#
#
# Механизм блокировки троса
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по тросам. Пользователь может указать точку, за которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до наиболее близкой к заданной точке наблюдательной позиции.
# Ранее инженеры из Технологического института Джорджии создали другого робота-ленивца для работы на тросе. Он так же состоит из двух частей, но имеет совершенно другую конструкцию и принцип работы. Он способен зацепляться концом одной части за трос и раскачивать другую, чтобы затем зацепиться ей. После этого он может отпустить первую часть и снова начать раскачиваться для того, чтобы двигаться дальше.
# Григорий Копиев

# %% [markdown]
# Отлично, сработало. Аналогично работает и с id, мы могли бы написать что-то вроде `page.find('div', id='maincontent')

# %% [markdown]
# #### Задание 1. Поиск элемента
#
# У вас есть переменная page, в которой хранится содержимое html-страницы. На странице есть элемент в тэге span, у которого атрибут id равен 'target'. Напишите строчку кода, которая присвоит текст этого элемента переменной value.
#
# Запишите ваш код в одну строку без пробелов. Используйте апострофы для передачи параметров, содержащих значение тэга и его id.

# %%
value = page.find('span', id='target').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-92295c402b83> in <module>
# ----> 1 value = page.find('span', id='target').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# #### Сбор нескольких элементов

# %% [markdown]
# Рассмотрим случай, когда нам нужно сразу много элементов. Пусть мы хотим получить название всех ссылок на странице в википедии про языки программирования.
#
# Для ссылок существует тэг <a\><\/a\>.  Давайте попробуем использовать find

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages'  
  
response = requests.get(url)  
page = BeautifulSoup(response.text, 'html.parser')  
page.find('a')  
# => <a id="top"></a>
# Out:
# <a id="top"></a>

# %% [markdown]
# Что-то пошло не так, и мы получили только одну ссылку, хотя на странице их явно больше. Это происходит, потому что метод find возвращает только первый подходящий элемент. Если нам надо их больше, нужно воспользоваться методом find_all

# %%
links = page.find_all('a')  
# Посмотрим, сколько всего мы получили  
print(len(links))  
# => 937
  
# Посмотрим на некоторые из ссылок  
print([link.text for link in links[500:510]])  
# => ['Orwell', 'Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail (programming language)', 'PARI/GP', 'Pascal']
# Out:
# 927
# ['Orwell', 'Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail (programming language)', 'PARI/GP', 'Pascal']

# %% [markdown]
# Ещё одна полезная вещь:  последовательный поиск, т.е. мы можем найти сначала один элемент, а потом сделать внутри него второй поиск. Давайте выведем названия всех ссылок для языков программирования, которые начинаются на цифру "1".

# %%
# Получаем элемент первого блока со ссылками  
first_block = page.find('div', class_='div-col')  
  
# Берём оттуда ссылки (ограничимся первыми десятью)  
links = first_block.find_all('a') 
print(links)
print([link.text for link in links[:10]])  
# => ['1C:Enterprise programming language']
# Out:
# [<a href="/wiki/A_Sharp_(.NET)" title="A Sharp (.NET)">A.NET</a>, <a href="/wiki/A-0_System" title="A-0 System">A-0 System</a>, <a href="/wiki/A%2B_(programming_language)" title="A+ (programming language)">A+</a>, <a href="/wiki/ABAP" title="ABAP">ABAP</a>, <a href="/wiki/ABC_(programming_language)" title="ABC (programming language)">ABC</a>, <a href="/wiki/ABC_ALGOL" title="ABC ALGOL">ABC ALGOL</a>, <a href="/wiki/ACC_(programming_language)" title="ACC (programming language)">ACC</a>, <a class="mw-redirect" href="/wiki/Accent_(programming_language)" title="Accent (programming language)">Accent</a>, <a href="/wiki/Distributed_Application_Specification_Language" title="Distributed Application Specification Language">Ace DASL (Distributed Application Specification Language)</a>, <a href="/wiki/Action!_(programming_language)" title="Action! (programming language)">Action!</a>, <a href="/wiki/ActionScript" title="ActionScript">ActionScript</a>, <a href="/wiki/Actor_(programming_language)" title="Actor (programming language)">Actor</a>, <a href="/wiki/Ada_(programming_language)" title="Ada (programming language)">Ada</a>, <a class="mw-redirect" href="/wiki/Adenine_(programming_language)" title="Adenine (programming language)">Adenine</a>, <a class="mw-redirect" href="/wiki/Agda_(theorem_prover)" title="Agda (theorem prover)">Agda</a>, <a class="mw-redirect" href="/wiki/Agilent_VEE" title="Agilent VEE">Agilent VEE</a>, <a href="/wiki/Agora_(programming_language)" title="Agora (programming language)">Agora</a>, <a href="/wiki/AIMMS" title="AIMMS">AIMMS</a>, <a href="/wiki/Aldor" title="Aldor">Aldor</a>, <a href="/wiki/Alef_(programming_language)" title="Alef (programming language)">Alef</a>, <a href="/wiki/Algebraic_Logic_Functional_programming_language" title="Algebraic Logic Functional programming language">ALF</a>, <a href="/wiki/ALGOL_58" title="ALGOL 58">ALGOL 58</a>, <a href="/wiki/ALGOL_60" title="ALGOL 60">ALGOL 60</a>, <a href="/wiki/ALGOL_68" title="ALGOL 68">ALGOL 68</a>, <a href="/wiki/ALGOL_W" title="ALGOL W">ALGOL W</a>, <a href="/wiki/Alice_(programming_language)" title="Alice (programming language)">Alice</a>, <a href="/wiki/Alma-0" title="Alma-0">Alma-0</a>, <a href="/wiki/AmbientTalk" title="AmbientTalk">AmbientTalk</a>, <a href="/wiki/Amiga_E" title="Amiga E">Amiga E</a>, <a href="/wiki/AMOS_(programming_language)" title="AMOS (programming language)">AMOS</a>, <a href="/wiki/AMPL" title="AMPL">AMPL</a>, <a href="/wiki/AngelScript" title="AngelScript">AngelScript</a>, <a href="/wiki/Apache_Pig" title="Apache Pig">Apache Pig latin</a>, <a class="mw-redirect" href="/wiki/Apex_(programming_language)" title="Apex (programming language)">Apex</a>, <a href="/wiki/APL_(programming_language)" title="APL (programming language)">APL</a>, <a class="mw-redirect" href="/wiki/App_Inventor_for_Android_(programming_language)" title="App Inventor for Android (programming language)">App Inventor for Android's visual block language</a>, <a href="/wiki/AppleScript" title="AppleScript">AppleScript</a>, <a href="/wiki/APT_(programming_language)" title="APT (programming language)">APT</a>, <a href="/wiki/Arc_(programming_language)" title="Arc (programming language)">Arc</a>, <a href="/wiki/ARexx" title="ARexx">ARexx</a>, <a href="/wiki/Argus_(programming_language)" title="Argus (programming language)">Argus</a>, <a href="/wiki/Assembly_language" title="Assembly language">Assembly language</a>, <a href="/wiki/AutoHotkey" title="AutoHotkey">AutoHotkey</a>, <a href="/wiki/AutoIt" title="AutoIt">AutoIt</a>, <a href="/wiki/AutoLISP" title="AutoLISP">AutoLISP / Visual LISP</a>, <a href="/wiki/Averest" title="Averest">Averest</a>, <a href="/wiki/AWK" title="AWK">AWK</a>, <a href="/wiki/Axum_(programming_language)" title="Axum (programming language)">Axum</a>]
# ['A.NET', 'A-0 System', 'A+', 'ABAP', 'ABC', 'ABC ALGOL', 'ACC', 'Accent', 'Ace DASL (Distributed Application Specification Language)', 'Action!']

# %% [markdown]
# В заключение заметим, что BeautifulSoup – достаточно мощная библиотека. Мы рассмотрели базовые возможности, но полный список гораздо шире. С ним можно ознакомиться в официальной документации: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# #### Задание 1 - Актёры
#
# Напишите функцию get_actors, которая по ссылке на страницу фильма на кинопоиске возвращает список актёров из колонки справа: https://www.kinopoisk.ru/top/lists/

# %% [markdown]
# NB: Если делать слишком часто запросы, кинопоиск начинает выдавать капчу, поэтому старайтесь при отладке не делать больше одного запроса в секунду

# %%
def get_actors(url):
    list_actors=[]
    response=requests.get(url)
    page=BeautifulSoup(response.text,'html.parser')
    actors=page.find_all('li',itemprop='actors')
    for actor in actors:
        list_actors.append(actor.text)
    return list_actors


get_actors('https://www.kinopoisk.ru/film/42326/')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001A7DA2C76C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     724             retries = retries.increment(
# --> 725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     726             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='www.kinopoisk.ru', port=443): Max retries exceeded with url: /film/42326/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A7DA2C76C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-47-57c6546d4373> in <module>
#      13
#      14
# ---> 15 get_actors('https://www.kinopoisk.ru/film/42326/')
#
# <ipython-input-47-57c6546d4373> in get_actors(url)
#       2
#       3     # Получаем данные, как и ранее
# ----> 4     response = requests.get(url)
#       5
#       6     # Теперь создадим объект BeautifulSoup, указывая html парсер
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.kinopoisk.ru', port=443): Max retries exceeded with url: /film/42326/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A7DA2C76C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %% [markdown]
# ## HTML-таблицы

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# При работе с web-страницами было бы здорово получать содержимое  таблиц в виде датафрейма. Рассмотрим страницу ключевых показателей Центрального банка РФ cbr.ru. Наша задача будет состоять в том, чтобы получить одну из таблиц виджетов в виде датафрейма. Например, таблицу цен на драгоценные металлы.

# %% [markdown]
# Метод read_html из pandas умеет автоматически находить на HTML-странице таблицы и возвращать их списком из датафреймов:

# %%
import pandas as pd  
url = 'https://www.cbr.ru/key-indicators/'  
# Таблица с драгметаллами оказалась второй по счёту  
pd.read_html(url)[0]
# Out:
#                  0           1           2
# 0           валюта  21.08.2020  22.08.2020
# 1  Доллар США  USD      737711      740999
# 2        Евро  EUR      874261      877343

# %% [markdown]
# Если этого не происходит, но вы уверены в том, что порядок таблиц на странице неизменен, то можно вручную найти нужную таблицу на странице. Этому случаю посвящены следующие шаги.

# %% [markdown]
# ### Поиск таблицы с помощью BeautifulSoup

# %% [markdown]
# Более надёжным решением является сначала получить только текст таблицы и передавать в pandas только её. Так же, как и в предыдущем разделе, используем requests и BeautifulSoup, чтобы получить данные со страницы.
#
# А теперь — внимание! В случае работы с сайтом Центробанка нам нужно будет учесть ещё один нюанс. С недавнего времени администраторы стали блокировать обращения к сайту, поступающие не от «живых» пользователей, а от компьютерных программ (в том числе от той, которую мы собираемся написать прямо сейчас). Есть ли шанс в таких условиях всё-таки получить данные, не открывая страницу в браузере?
#
# Безусловно, это возможно. Безвыходных положений вообще не бывает, особенно в программировании! Один из способов справиться с ситуацией — «притвориться» браузером :).
#
# Каждый запрос, отправляемый с помощью команды get, имеет заголовок. Если заголовок не задан явно, то он создаётся автоматически, и туда добавляется информация в том числе о том, кто является субъектом (или источником) запроса — человек или программа. Чтобы «притвориться» браузером, нам просто нужно вручную дописать нужные сведения в этот заголовок. Подробнее о таком подходе можно почитать в этой статье.
#
# Итоговый вариант кода после добавления заголовка должен выглядеть так:

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests  
  
url = 'https://www.cbr.ru/key-indicators/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %% [markdown]
# Далее нажимаем 'Исследовать элемент' в меню браузера на виджете с драгоценными металлами:

# %% [markdown]
# Нам необходимо добраться до кода таблицы, который начинается с тэга <\table>. Таблиц на странице много, поэтому указываем путь к таблице виджета драгоценных металлов применяя знания полученные ранее:

# %%
all_blocks = soup.find_all('div', class_='key-indicator_content offset-md-2')
# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[1].find('table')

# %% [markdown]
# Сейчас наша таблица записана в HTML-коде:

# %%
print(data)
# Out:
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">рублей за грамм</td>
# <td class="value td-w-4 _end">22.08.2020</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Золото</div>
# <div class="col-md-3 offset-md-1 _subinfo">Au</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">4 604,75</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Серебро</div>
# <div class="col-md-3 offset-md-1 _subinfo">Ag</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">63,97</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Платина</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pt</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">2 172,72</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Палладий</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pd</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">5 193,56</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Для перевода ее в датафрейм используем метод read_html. Метод возвращает список датафреймов. В нашем случае датафрейм будет только один, поэтому сразу берем первый элемент:

# %%
df = pd.read_html(str(data))[0]  
df
# Out:
#                  0           1
# 0  рублей за грамм  22.08.2020
# 1        Золото Au    4 604,75
# 2       Серебро Ag        6397
# 3       Платина Pt    2 172,72
# 4      Палладий Pd    5 193,56

# %% [markdown]
# Датафрейм получен! Теперь можно работать с ним средствами Pandas.

# %% [markdown]
# #### Задание 2 - Рейтинг банков
#
# Напишите программу, которая забирает данные из таблицы рейтинга банков с https://www.banki.ru/banks/ratings/, делает из него датафрейм и сохраняет его в переменую df.

# %%
url = 'https://www.banki.ru/banks/ratings/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')
# Данные таблицы с банками находятся в первом блоке
data = soup.find('table')
df = pd.read_html(str(data), header=None)[0]
df.columns = ['rating','name','from',
                     'to','diff','diff %']
df
# Out:
#    rating                                               name            from  \
# 0       1     Сбербанк России лицензия № 1481, Москва и обл.  31 415 098 095
# 1       2        ВТБ лицензия № 1000, Санкт-Петербург и обл.  15 269 639 853
# 2       3          Газпромбанк лицензия № 354, Москва и обл.   7 031 457 276
# 3       4  Национальный Клиринговый Центр лицензия № 3466...   4 487 642 224
# 4       5          Альфа-Банк лицензия № 1326, Москва и обл.   3 937 290 975
# 5       6      Россельхозбанк лицензия № 3349, Москва и обл.   3 619 545 036
# 6    7 +1  Московский Кредитный Банк лицензия № 1978, Мос...   2 841 108 461
# 7    8 −1       Банк Открытие лицензия № 2209, Москва и обл.   2 834 457 224
# 8       9        Совкомбанк лицензия № 963, Костромская обл.   1 574 405 911
# 9      10         ЮниКредит Банк лицензия № 1, Москва и обл.   1 447 538 742
# 10     11             Росбанк лицензия № 2272, Москва и обл.   1 392 055 244
# 11  12 +1      Райффайзенбанк лицензия № 3292, Москва и обл.   1 328 782 624
# 12  13 −1               Траст лицензия № 3279, Москва и обл.   1 296 257 848
# 13     14      Россия лицензия № 328, Санкт-Петербург и обл.   1 077 139 159
# 14     15  Всероссийский Банк Развития Регионов лицензия ...     820 701 631
# 15  16 +1       Тинькофф Банк лицензия № 2673, Москва и обл.     710 608 163
# 16  17 −1  Санкт-Петербург лицензия № 436, Санкт-Петербур...     709 066 567
# 17  18 +3             БМ-Банк лицензия № 2748, Москва и обл.     670 040 063
# 18  19 −1                 Ак Барс лицензия № 2590, Татарстан     630 984 053
# 19  20 −1            Ситибанк лицензия № 2557, Москва и обл.     620 062 723
# 20  21 −1         Новикомбанк лицензия № 2546, Москва и обл.     537 671 079
# 21  22 +1          Банк Уралсиб лицензия № 30, Москва и обл.     521 639 281
# 22  23 −1           Почта Банк лицензия № 650, Москва и обл.     517 152 553
# 23     24            СМП Банк лицензия № 3368, Москва и обл.     484 851 977
# 24     25  Московский Индустриальный Банк лицензия № 912,...     422 763 903
# 25  26 +1         Банк ДОМ.РФ лицензия № 2312, Москва и обл.     396 157 419
# 26  27 −1  Московский Областной Банк лицензия № 1751, Мос...     395 753 975
# 27     28            Пересвет лицензия № 2110, Москва и обл.     336 370 237
# 28     29    Русский Стандарт лицензия № 2289, Москва и обл.     327 412 353
# 29     30  Сургутнефтегазбанк лицензия № 588, Ханты-Манси...     289 832 125
# 30     31         Возрождение лицензия № 1439, Москва и обл.     276 317 249
# 31     32        Абсолют Банк лицензия № 2306, Москва и обл.     274 742 082
# 32  33 +1                  РНКБ лицензия № 1354, Симферополь     264 257 497
# 33  34 −1     Хоум Кредит Банк лицензия № 316, Москва и обл.     259 344 959
# 34  35 +2  Уральский Банк Реконструкции и Развития лиценз...     247 331 972
# 35     36      Восточный Банк лицензия № 1460, Амурская обл.     243 027 773
# 36  37 +3            МТС Банк лицензия № 2268, Москва и обл.     234 875 523
# 37     38          Банк Зенит лицензия № 3255, Москва и обл.     230 312 450
# 38     39  Национальный Расчетный Депозитарий лицензия № ...     228 048 705
# 39  40 +1      Инвестторгбанк лицензия № 2763, Москва и обл.     201 063 993
# 40  41 −6            ИНГ Банк лицензия № 2495, Москва и обл.     200 462 851
# 41     42    Транскапиталбанк лицензия № 2210, Москва и обл.     174 318 354
# 42  43 +3        Росэксимбанк лицензия № 2790, Москва и обл.     173 923 774
# 43  44 +1    Ренессанс Кредит лицензия № 3354, Москва и обл.     164 244 160
# 44  45 −1            ОТП Банк лицензия № 2766, Москва и обл.     160 700 607
# 45  46 +1        Сетелем Банк лицензия № 2168, Москва и обл.     152 802 826
# 46  47 +2     Русфинанс Банк лицензия № 1792, Самарская обл.     149 934 643
# 47     48       Запсибкомбанк лицензия № 918, Тюменская обл.     149 735 077
# 48  49 +3            МСП Банк лицензия № 3340, Москва и обл.     145 157 615
# 49     50  Кредит Европа Банк лицензия № 3311, Москва и обл.     142 639 977
#
#                 to          diff   diff %
# 0   30 759 269 658  +655 828 437   +2,13%
# 1   15 029 152 247  +240 487 606   +1,60%
# 2    7 092 861 002   −61 403 726   −0,87%
# 3    4 279 004 841  +208 637 383   +4,88%
# 4    3 908 179 939   +29 111 036   +0,74%
# 5    3 506 105 175  +113 439 861   +3,24%
# 6    2 710 108 949  +130 999 512   +4,83%
# 7    2 733 425 636  +101 031 588   +3,70%
# 8    1 504 044 466   +70 361 445   +4,68%
# 9    1 473 088 658   −25 549 916   −1,73%
# 10   1 355 292 312   +36 762 932   +2,71%
# 11   1 302 470 979   +26 311 645   +2,02%
# 12   1 307 595 844   −11 337 996   −0,87%
# 13   1 081 891 658    −4 752 499   −0,44%
# 14     791 289 461   +29 412 170   +3,72%
# 15     692 503 246   +18 104 917   +2,61%
# 16     695 870 216   +13 196 351   +1,90%
# 17     512 871 803  +157 168 260  +30,64%
# 18     630 480 875      +503 178   +0,08%
# 19     580 468 556   +39 594 167   +6,82%
# 20     545 644 459    −7 973 380   −1,46%
# 21     511 714 871    +9 924 410   +1,94%
# 22     511 788 106    +5 364 447   +1,05%
# 23     507 838 419   −22 986 442   −4,53%
# 24     427 967 163    −5 203 260   −1,22%
# 25     386 434 613    +9 722 806   +2,52%
# 26     412 080 401   −16 326 426   −3,96%
# 27     335 473 337      +896 900   +0,27%
# 28     325 940 687    +1 471 666   +0,45%
# 29     293 070 098    −3 237 973   −1,10%
# 30     290 633 707   −14 316 458   −4,93%
# 31     275 259 623      −517 541   −0,19%
# 32     260 455 133    +3 802 364   +1,46%
# 33     262 827 620    −3 482 661   −1,33%
# 34     244 292 047    +3 039 925   +1,24%
# 35     246 060 073    −3 032 300   −1,23%
# 36     210 216 577   +24 658 946  +11,73%
# 37     232 765 734    −2 453 284   −1,05%
# 38     217 715 212   +10 333 493   +4,75%
# 39     200 125 677      +938 316   +0,47%
# 40     249 839 354   −49 376 503  −19,76%
# 41     171 832 654    +2 485 700   +1,45%
# 42     161 186 496   +12 737 278   +7,90%
# 43     165 742 033    −1 497 873   −0,90%
# 44     167 679 440    −6 978 833   −4,16%
# 45     151 989 196      +813 630   +0,54%
# 46     147 185 820    +2 748 823   +1,87%
# 47     148 736 386      +998 691   +0,67%
# 48     138 674 332    +6 483 283   +4,68%
# 49     143 155 570      −515 593   −0,36%

# %% [markdown]
# Возможно, кто-то обратил внимание, что когда мы "стягиваем" таблицу стоимости металлов, то значение стоимости серебра (самого дешёвого из представленных металлов) может превосходить стоимость более дорогих металлов. Это связано  с отсутствием указания разделителей тысяч и дробной части.
#
# df = pd.read_html(str(data), thousands =" ", decimal = ",")[0]  может исправить эту ситуацию.

# %% [markdown]
# ## Введение в API

# %% [markdown]
# В предыдущих разделах мы собирали полезную информацию с различных сайтов с выделением правильных тэгов – это довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка, или владельцы сайтов защищаются от ботов капчей.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым API (application programming interface, программный интерфейс приложения). Это специальные разделы сайта, где информацию можно получать без разметки, формат запросов – ответов зафиксирован, и они созданы специально, чтобы облегчить жизнь сторонним разработчикам.
#
# Мы уже видели, как https://www.cbr-xml-daily.ru возвращает данные о валютах в json-формате, и это может считаться API. В этом разделе мы на примере ВКонтакте посмотрим особенности API, характерные для более крупных сайтов.

# %% [markdown]
# #### Сервисный токен

# %% [markdown]
# Для того чтобы начать работать с API ВКонтакте, необходимо получить сервисный токен (ключ) авторизации.
#
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени. Сервисный токен для нашей задачи создается вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на страницу https://vk.com/editapp?act=create, чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и оставьте значение платформы "Standalone-приложение":
#
# После подтверждения создания приложения в приложении ВК или по СМС зайдите в настройки:

# %% [markdown]
# #### Запрос к API

# %% [markdown]
# Для примера работы с API мы будем получать данные для статистических отчетов произвольной группы, например:
#
# - соотношение мужчин и женщин в группе;
# - статистика географии пользователей;
# - другие данные для аналитики групп конкурентов.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Перейдите по следующей ссылке в браузере, подставив вместо слова "TOKEN" сервисный токен из прошлого шага:
#
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN
#
# Результат:

# %%
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true}]}

# %% [markdown]
# Сейчас мы сделали GET-запрос к API ВКонтакте, который состоит из следующих частей:
#
# - https://api.vk.com/method — домен и URL запроса API: обычно не меняется;
# - users.get — название метода, который отдает определенный отчет; нашем случае это метод для получения информации о пользователе;
# - user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию, и номер версии API;
# - token, который выдается только пользователям, имеющим право просматривать определенные данные, например, показания счетчиков - Яндекс, метрики вашего проекта: на все остальные запросы без корректного токена система отвечает отказом.
#
# Если мы посмотрим документацию метода users.get, то увидим, что в ней описано множество других параметров, которые можно получить о пользователе: дата рождения, пол, родной город и другие.
#
# Словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал). Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):

# %%
# https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN

# %% [markdown]
# Результат:

# %%
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}  
# Примечание: значение 2 у параметра 'sex' означает мужской пол.

# %% [markdown]
# #### Запрос к API из кода

# %% [markdown]
# Мы делали запрос в браузере, теперь давайте сделаем запрос из кода. Будем пользоваться всё той же библиотекой requests.

# %%
url = 'https://api.vk.com/method/users.get'
token = 'b999d26bb999d26bb999d26bc6b9ea49cebb999b999d26be6da711b86f2c898d1bb0150'
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}  
  
# Мы можем выставить параметры запроса через аргумент params  
response = requests.get(url, params=params)  
response.text  
# => '{"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}'
# Out:
# '{"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}'

# %% [markdown]
# Мы получили строку в формате JSON. Как мы помним по первому разделу, её можно преобразовать в словарь методом json и после этого обращаться к различным полям. Кроме того, такие большие вложенные словари нагляднее выводить с помощью функции pprint (~pretty print, красивый вывод), которым мы и воспользуемся

# %%
from pprint import pprint  
  
pprint(response.json())  
# =>   
# {'response': [{'bdate': '10.10.1984',  
#                'can_access_closed': True,  
#                'first_name': 'Павел',  
#                'id': 1,  
#                'is_closed': False,
#                'last_name': 'Дуров',  
#                'sex': 2}]}  
  
user = response.json()['response'][0]  
  
# Выведем дату рождения  
print(user['bdate'])  
# => 10.10.1984  
  
# Выведем имя  
print(user['first_name'])  
# => Павел
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}
# 10.10.1984
# Павел

# %% [markdown]
# Данный метод позволяет запрашивать сразу много пользователей (до 1000).  Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате, например: '1,2,3'.

# %%
ids = ",".join(map(str, range(1, 4)))  
print(ids)  
# => 1,2,3  
  
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'}  
  
pprint(requests.get(url, params=params).json()) 
# {'response': [{'can_access_closed': True,  
#                'first_name': 'Павел',  
#                'id': 1,  
#                ''is_closed': False',  
#                'last_name': 'Дуров'},  
#               {'can_access_closed': False,  
#                'first_name': 'Александра',  
#                'id': 2,  
#                'is_closed': True,  
#                'last_name': 'Владимирова'},  
#               {'deactivated': 'deleted',  
#                'first_name': 'DELETED',  
#                'id': 3,  
#                'last_name': ''}]}
# Out:
# 1,2,3
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# #### Задание 1 - Гендерный баланс
#
# Используя API, определите долю женщин(sex=1) среди пользователей с id от 1 до 500. Иногда вам будут попадать пользователи, у которых пол не указан (sex=0), их не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после запятой, например, 0.55
#
# Пример: если у нас будет 300 пользователей sex=1, 100 пользователей с sex=2 и 100 пользователей с sex=0, то в ответе должно быть 0.75

# %%
ids = ",".join(map(str, range(1, 501)))

params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}

user = requests.get(url, params=params).json()['response']  

users_sex = {}

for i in range(0, 500):

    users_sex.update({i: [user[i]['id'], user[i]['sex']]})
    
df = pd.DataFrame.from_dict(users_sex, orient='index',
                       columns=['id', 'sex'])

print(df['sex'].value_counts())
# Out:
# 2    218
# 1    203
# 0     79
# Name: sex, dtype: int64
# 500

# %% [markdown]
# #### Ограничения API

# %% [markdown]
# В прошлом блоке мы собрали информацию о небольшом наборе пользователей. Теперь перейдем к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
# - не могут учитывать всех особенностей вашего проекта;
# - считают фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# - не всегда бесплатны и вряд ли позволят работать с большими объемами данных.
#
# В этом разделе мы научимся считать произвольные метрики групп, собирая данные из API.
#
# В текущем шаге мы научимся работать с двумя ограничениями, которые свойственны практически всем системам:
#
# - ограничение на количество вызовов в единицу времени;
# - ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в секунду сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчетов можно выгрузить, уложившись в этот лимит (например, как мы получили информацию о 500 пользователях в прошлом упражнении). Однако второе ограничение не удастся «обойти» в случае выгрузки больших отчетов. Например, чтобы получить список всех пользователей очень популярной группы, серверу, возможно, придется отправить вам разом лист из миллионов записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/mountelbrus.
#
# Посмотрим в документации, какие методы нам доступны для групп. Для получения списка пользователей группы видим метод groups.getMembers.
#
# Согласно документации, обязательным параметром является ID или короткое имя группы. В нашем случае это mountelbrus: https://vk.com/mountelbrus. Тестируем, как работает метод в самом простом случае:

# %%
url = 'https://api.vk.com/method/groups.getMembers'  
params = {  
    'group_id': 'mountelbrus',  
    'v': 5.95,  
    'access_token': token  
}  
response = requests.get(url, params = params)  
data = response.json()  
print(data)  
# => {'response': {'count': 65921, 'items': [161, 273, 710, 1157...  

 
len(data['response']['items'])  
# => 1000
# Out:
# {'response': {'count': 66145, 'items': [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5453, 5678, 5818, 5970, 6172, 6528, 6706, 7224, 7303, 7638, 8212, 8376, 8422, 9006, 9322, 9640, 9808, 10133, 10361, 10531, 11246, 11788, 12129, 12541, 12757, 12915, 12976, 12990, 13188, 13549, 13695, 14033, 14644, 14742, 15018, 15140, 15421, 16328, 16608, 17522, 17656, 17670, 18226, 18248, 18423, 18958, 19072, 19232, 19405, 19483, 19568, 19691, 19720, 20417, 20598, 20866, 20934, 20980, 21179, 21386, 21760, 22123, 22135, 22726, 23011, 23217, 23256, 23360, 23932, 24275, 24985, 25018, 25096, 25166, 25310, 25394, 25814, 25930, 25975, 26034, 26205, 26543, 26828, 27023, 27513, 27536, 27659, 27670, 28879, 29166, 29450, 29677, 29805, 30168, 30518, 30760, 31012, 31926, 32019, 32528, 33259, 33299, 33795, 34777, 34811, 35170, 35244, 35300, 35868, 36811, 37082, 37311, 37455, 37496, 38193, 38258, 39030, 39286, 39425, 39538, 39702, 39737, 39738, 40089, 40933, 40984, 41195, 41300, 41682, 42180, 42282, 42385, 42464, 42931, 43000, 43095, 43100, 43471, 43653, 43881, 44094, 44261, 44585, 45239, 45710, 46284, 46964, 47480, 47999, 48081, 48399, 49048, 49681, 50120, 50623, 52170, 53359, 53485, 53518, 54620, 54849, 54872, 54948, 55616, 55761, 55979, 56741, 56799, 56812, 58017, 58185, 58660, 60233, 60452, 60621, 61574, 61601, 63200, 63389, 63534, 63587, 63914, 63957, 64478, 64794, 65307, 65906, 65938, 66068, 66097, 66111, 66381, 66423, 67109, 67141, 67424, 67522, 67594, 68263, 68323, 68374, 68869, 69409, 69605, 69705, 69787, 69872, 70088, 70339, 70553, 71231, 71621, 71627, 71722, 72208, 72654, 72657, 73229, 73349, 73838, 73932, 74005, 74356, 74613, 74769, 75018, 75555, 75685, 76497, 76528, 76964, 77261, 77294, 77367, 77491, 77777, 77818, 77892, 78330, 78372, 78557, 79098, 79286, 79448, 79464, 80367, 80923, 81121, 81520, 81771, 82055, 82121, 82172, 82849, 82880, 82899, 83458, 83593, 84193, 84300, 85170, 85293, 85414, 87135, 87232, 87840, 88595, 88853, 90107, 90121, 90706, 91235, 91498, 91529, 92506, 92796, 92920, 93545, 93746, 94155, 94164, 94242, 95105, 95579, 95780, 96377, 96731, 96880, 97051, 97328, 97503, 98806, 100103, 100589, 100870, 100947, 100971, 101064, 101467, 102026, 102061, 102502, 102607, 102609, 102811, 103073, 103953, 104138, 104291, 104316, 104472, 104792, 105003, 105213, 105482, 105598, 106335, 106784, 106922, 107009, 107137, 107242, 107267, 107309, 107341, 107489, 107740, 108255, 108420, 108956, 109311, 109978, 110368, 110541, 111023, 111526, 111542, 111819, 113305, 113693, 113791, 113994, 114129, 115692, 116136, 117385, 117734, 118077, 118207, 118389, 118413, 118964, 119007, 119335, 119423, 119500, 120298, 121050, 121896, 122483, 122556, 123072, 123610, 124511, 124925, 125168, 126210, 126641, 126810, 126940, 128657, 129061, 129474, 130669, 130752, 131998, 132144, 132587, 133374, 133504, 133938, 134384, 134984, 135072, 135401, 136030, 136463, 136668, 137288, 138142, 139418, 139624, 140089, 140499, 140924, 141263, 141935, 142026, 142260, 143686, 144303, 145244, 145248, 145502, 145621, 146767, 146819, 146841, 146918, 146995, 147718, 148603, 148618, 148833, 149125, 149240, 150772, 151687, 151846, 151987, 152355, 154408, 154520, 154938, 156799, 156907, 156935, 157117, 157412, 157661, 157696, 158061, 158313, 159338, 160805, 160925, 161214, 161275, 161299, 161312, 161337, 161501, 161677, 161921, 161977, 163441, 164579, 165031, 165317, 165583, 165724, 166333, 166510, 166881, 167031, 168179, 169621, 170994, 171186, 171952, 172259, 173211, 173245, 173657, 173952, 174349, 174494, 174600, 174683, 174927, 174995, 175219, 175419, 175469, 175960, 177505, 178092, 178298, 179874, 180665, 180687, 180697, 181090, 181559, 181607, 181664, 181952, 182322, 182436, 182624, 183093, 183740, 184032, 184418, 185366, 185441, 185890, 186233, 186584, 186610, 186705, 186761, 186826, 186839, 186914, 187146, 187306, 188950, 189119, 189390, 189913, 190835, 191113, 191499, 191688, 192041, 192252, 192414, 192484, 192545 ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-146-34b6aea08d82> in <module>
#      10 # => {'response': {'count': 65921, 'items': [161, 273, 710, 1157...
#      11
# ---> 12 data['response']['items'][49999]
#      13
#      14 len(data['response']['items'])
#
# IndexError: list index out of range

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 65 000, а получили мы только первую тысячу пользователей группы. Судя по описанию параметра count в документации, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей воспользуемся параметрами count и offset: будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), а в каждом следующем шаге цикла увеличим смещение offset на величину count.
#
# Сначала напишем цикл выгрузки первых 20 пользователей со значением count = 5. Т.е. цикл будет выгружать за 1 запрос по 5 пользователей, пока не выгрузит первые 20. Это позволит нам проверить корректность работы цикла перед тем, как делать большие и долгие выгрузки.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки с 1000 пользователей, чтобы было с чем сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20]  
print(users_for_checking)
# Out:
# [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5453]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по 5 за раз

# %%
count = 1000  
offset = 0  
user_ids = []
max_count = data['response']['count']  
while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'mountelbrus',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': token  
    }     
    # такой же запрос как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']   
  
    # увеличиваем смещение на количество строк выгрузки  
    offset += count  
      
# Выгружаю 5 пользователей с offset = 0  
# Выгружаю 5 пользователей с offset = 5  
# Выгружаю 5 пользователей с offset = 10  
# Выгружаю 5 пользователей с offset = 15  
print(user_ids)  
# => [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5453]  
  
user_ids == users_for_checking  
# => True
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Выгружаю 1000 пользователей с offset = 1000
# Выгружаю 1000 пользователей с offset = 2000
# Выгружаю 1000 пользователей с offset = 3000
# Выгружаю 1000 пользователей с offset = 4000
# Выгружаю 1000 пользователей с offset = 5000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 7000
# Выгружаю 1000 пользователей с offset = 8000
# Выгружаю 1000 пользователей с offset = 9000
# Выгружаю 1000 пользователей с offset = 10000
# Выгружаю 1000 пользователей с offset = 11000
# Выгружаю 1000 пользователей с offset = 12000
# Выгружаю 1000 пользователей с offset = 13000
# Выгружаю 1000 пользователей с offset = 14000
# Выгружаю 1000 пользователей с offset = 15000
# Выгружаю 1000 пользователей с offset = 16000
# Выгружаю 1000 пользователей с offset = 17000
# Выгружаю 1000 пользователей с offset = 18000
# Выгружаю 1000 пользователей с offset = 19000
# Выгружаю 1000 пользователей с offset = 20000
# Выгружаю 1000 пользователей с offset = 21000
# Выгружаю 1000 пользователей с offset = 22000
# Выгружаю 1000 пользователей с offset = 23000
# Выгружаю 1000 пользователей с offset = 24000
# Выгружаю 1000 пользователей с offset = 25000
# Выгружаю 1000 пользователей с offset = 26000
# Выгружаю 1000 пользователей с offset = 27000
# Выгружаю 1000 пользователей с offset = 28000
# Выгружаю 1000 пользователей с offset = 29000
# Выгружаю 1000 пользователей с offset = 30000
# Выгружаю 1000 пользователей с offset = 31000
# Выгружаю 1000 пользователей с offset = 32000
# Выгружаю 1000 пользователей с offset = 33000
# Выгружаю 1000 пользователей с offset = 34000
# Выгружаю 1000 пользователей с offset = 35000
# Выгружаю 1000 пользователей с offset = 36000
# Выгружаю 1000 пользователей с offset = 37000
# Выгружаю 1000 пользователей с offset = 38000
# Выгружаю 1000 пользователей с offset = 39000
# Выгружаю 1000 пользователей с offset = 40000
# Выгружаю 1000 пользователей с offset = 41000
# Выгружаю 1000 пользователей с offset = 42000
# Выгружаю 1000 пользователей с offset = 43000
# Выгружаю 1000 пользователей с offset = 44000
# Выгружаю 1000 пользователей с offset = 45000
# Выгружаю 1000 пользователей с offset = 46000
# Выгружаю 1000 пользователей с offset = 47000
# Выгружаю 1000 пользователей с offset = 48000
# Выгружаю 1000 пользователей с offset = 49000
# Выгружаю 1000 пользователей с offset = 50000
# Выгружаю 1000 пользователей с offset = 51000
# Выгружаю 1000 пользователей с offset = 52000
# Выгружаю 1000 пользователей с offset = 53000
# Выгружаю 1000 пользователей с offset = 54000
# Выгружаю 1000 пользователей с offset = 55000
# Выгружаю 1000 пользователей с offset = 56000
# Выгружаю 1000 пользователей с offset = 57000
# Выгружаю 1000 пользователей с offset = 58000
# Выгружаю 1000 пользователей с offset = 59000
# Выгружаю 1000 пользователей с offset = 60000
# Выгружаю 1000 пользователей с offset = 61000
# Выгружаю 1000 пользователей с offset = 62000
# Выгружаю 1000 пользователей с offset = 63000
# Выгружаю 1000 пользователей с offset = 64000
# Выгружаю 1000 пользователей с offset = 65000
# Выгружаю 1000 пользователей с offset = 66000
# [161, 273, 710, 1157, 1364, 1858, 2306, 3516, 3857, 4316, 4592, 4646, 4765, 4901, 4969, 4992, 5118, 5121, 5438, 5453, 5678, 5818, 5970, 6172, 6528, 6706, 7224, 7303, 7638, 8212, 8376, 8422, 9006, 9322, 9640, 9808, 10133, 10361, 10531, 11246, 11788, 12129, 12541, 12757, 12915, 12976, 12990, 13188, 13549, 13695, 14033, 14644, 14742, 15018, 15140, 15421, 16328, 16608, 17522, 17656, 17670, 18226, 18248, 18423, 18958, 19072, 19232, 19405, 19483, 19568, 19691, 19720, 20417, 20598, 20866, 20934, 20980, 21179, 21386, 21760, 22123, 22135, 22726, 23011, 23217, 23256, 23360, 23932, 24275, 24985, 25018, 25096, 25166, 25310, 25394, 25814, 25930, 25975, 26034, 26205, 26543, 26828, 27023, 27513, 27536, 27659, 27670, 28879, 29166, 29450, 29677, 29805, 30168, 30518, 30760, 31012, 31926, 32019, 32528, 33259, 33299, 33795, 34777, 34811, 35170, 35244, 35300, 35868, 36811, 37082, 37311, 37455, 37496, 38193, 38258, 39030, 39286, 39425, 39538, 39702, 39737, 39738, 40089, 40933, 40984, 41195, 41300, 41682, 42180, 42282, 42385, 42464, 42931, 43000, 43095, 43100, 43471, 43653, 43881, 44094, 44261, 44585, 45239, 45710, 46284, 46964, 47480, 47999, 48081, 48399, 49048, 49681, 50120, 50623, 52170, 53359, 53485, 53518, 54620, 54849, 54872, 54948, 55616, 55761, 55979, 56741, 56799, 56812, 58017, 58185, 58660, 60233, 60452, 60621, 61574, 61601, 63200, 63389, 63534, 63587, 63914, 63957, 64478, 64794, 65307, 65906, 65938, 66068, 66097, 66111, 66381, 66423, 67109, 67141, 67424, 67522, 67594, 68263, 68323, 68374, 68869, 69409, 69605, 69705, 69787, 69872, 70088, 70339, 70553, 71231, 71621, 71627, 71722, 72208, 72654, 72657, 73229, 73349, 73838, 73932, 74005, 74356, 74613, 74769, 75018, 75555, 75685, 76497, 76528, 76964, 77261, 77294, 77367, 77491, 77777, 77818, 77892, 78330, 78372, 78557, 79098, 79286, 79448, 79464, 80367, 80923, 81121, 81520, 81771, 82055, 82121, 82172, 82849, 82880, 82899, 83458, 83593, 84193, 84300, 85170, 85293, 85414, 87135, 87232, 87840, 88595, 88853, 90107, 90121, 90706, 91235, 91498, 91529, 92506, 92796, 92920, 93545, 93746, 94155, 94164, 94242, 95105, 95579, 95780, 96377, 96731, 96880, 97051, 97328, 97503, 98806, 100103, 100589, 100870, 100947, 100971, 101064, 101467, 102026, 102061, 102502, 102607, 102609, 102811, 103073, 103953, 104138, 104291, 104316, 104472, 104792, 105003, 105213, 105482, 105598, 106335, 106784, 106922, 107009, 107137, 107242, 107267, 107309, 107341, 107489, 107740, 108255, 108420, 108956, 109311, 109978, 110368, 110541, 111023, 111526, 111542, 111819, 113305, 113693, 113791, 113994, 114129, 115692, 116136, 117385, 117734, 118077, 118207, 118389, 118413, 118964, 119007, 119335, 119423, 119500, 120298, 121050, 121896, 122483, 122556, 123072, 123610, 124511, 124925, 125168, 126210, 126641, 126810, 126940, 128657, 129061, 129474, 130669, 130752, 131998, 132144, 132587, 133374, 133504, 133938, 134384, 134984, 135072, 135401, 136030, 136463, 136668, 137288, 138142, 139418, 139624, 140089, 140499, 140924, 141263, 141935, 142026, 142260, 143686, 144303, 145244, 145248, 145502, 145621, 146767, 146819, 146841, 146918, 146995, 147718, 148603, 148618, 148833, 149125, 149240, 150772, 151687, 151846, 151987, 152355, 154408, 154520, 154938, 156799, 156907, 156935, 157117, 157412, 157661, 157696, 158061, 158313, 159338, 160805, 160925, 161214, 161275, 161299, 161312, 161337, 161501, 161677, 161921, 161977, 163441, 164579, 165031, 165317, 165583, 165724, 166333, 166510, 166881, 167031, 168179, 169621, 170994, 171186, 171952, 172259, 173211, 173245, 173657, 173952, 174349, 174494, 174600, 174683, 174927, 174995, 175219, 175419, 175469, 175960, 177505, 178092, 178298, 179874, 180665, 180687, 180697, 181090, 181559, 181607, 181664, 181952, 182322, 182436, 182624, 183093, 183740, 184032, 184418, 185366, 185441, 185890, 186233, 186584, 186610, 186705, 186761, 186826, 186839, 186914, 187146, 187306, 188950, 189119, 189390, 189913, 190835, 191113, 191499, 191688, 192041, 192252, 192414, 192484, 192545, 193255, 195252, 195858, 196380, 19765 ...
# False

# %% [markdown]
# См. статью "Получение участников сообщества vk.com за считанные секунды" https://habr.com/ru/post/248725/

# %% [markdown]
# Видим, что подход корректно работает. Теперь мы можем получить всех пользователей, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# #### Задание 1 - Юбилейный пользователь
#
# Используя API, определите id пятидесятитысячного пользователя в группе mountelbrus . Т.е. если бы у нас не было ограничения на размер запроса, то мы бы запросили data['response']['items'][49999] .

# %%
user_ids[49999]
# Out:
# 225379369

# %% [markdown]
# #### Ограничение по частоте запросов

# %% [markdown]
# В API частот добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали  сервер. Подобное ограничение есть и у ВКонтакте, в документации которой указано, что можно делать не более 3-х запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, т.к. периодичность отправки запросов будет искусственно замедлена. Воспользуемся библиотекой time и методом sleep (пауза в 0.5 секунды добавлена в конце цикла):

# %%
import time  
  
count = 1000  
offset = 0  
user_ids = []  
while offset < 10000:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'mountelbrus',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': token  
    }    
    # такой же запрос, как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']    
  
    # увеличиваем смещение на количество строк выгрузки  
    offset += count  
    
    print('Ожидаю 0.5 секунды...')  
    time.sleep(0.5)
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 1000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 2000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 3000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 4000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 5000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 6000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 7000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 8000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 9000
# Ожидаю 0.5 секунды...

# %% [markdown]
# #### Лайки, репосты и комментарии

# %% [markdown]
# Ещё одна полезная вещь, которую можно получить,  —  это количество взаимодействий с постами через API новостной ленты. На данном этапе будем использовать самый простой вариант: берем последние 10 постов группы. Мы продолжаем работать с группой https://vk.com/mountelbrus.
#
# Начнем с  формирования запроса к API ВКонтакте методом wall.get():

# %%
import requests  
from pprint import pprint  
  
url = 'https://api.vk.com/method/wall.get'  
params = {  
    'domain': 'mountelbrus',  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': token,  
    'v': 5.95  
}  
response = requests.get(url, params = params)  
response.json()
# => {'response': {'count': 705,  
#      'items': [{'id': 13401',  
#        'from_id': -9690799,  
#        'owner_id': -9690799,  
#        'date': 1596525625,  
#        'marked_as_ads': 0,  
#        'post_type': 'post',
# ...
# Out:
# {'response': {'count': 710,
#   'items': [{'id': 13482,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1598188550,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Последние 10 туров на Эльбрус в этом сезоне, которые еще доступны для бронирования. \nРасписание 2020, описание маршрутов и бронирование здесь: https://strahu-net.com/raspisanie-turov-na-elbrus/?year=2020',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1598188543,
#        'id': 457242581,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '04ffc873146b0f0bf5',
#        'post_id': 13482,
#        'sizes': [{'height': 65,
#          'url': 'https://sun9-56.userapi.com/2jgpYP7K7Bn0KUQRBrBs5sTiNVYS8oNyDJwBwQ/-NQdNzlSXTI.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-2.userapi.com/IPbtbVfkd3KdYy41z6eR2CJJqY79FJgdn8bATw/ghCgd2y6Ymk.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 133,
#          'url': 'https://sun9-71.userapi.com/GALNTGZAbfiizVPaGERbJmOrUw5c84TTpHAS0g/0b0kiSnKV2I.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 213,
#          'url': 'https://sun9-68.userapi.com/wyeS3dzKrzeDT4ZvyeBSymGhEslQrH17svWIKA/dXkucKOkUVo.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 340,
#          'url': 'https://sun9-1.userapi.com/E0siT_rAEA8jm9VkO-wRsh0qzFIUV_dtCxFi0g/1yVVYVc14xs.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 37,
#          'url': 'https://sun9-65.userapi.com/r_nNdYwZAo3FT7LzhFUz1pxD8i67vWUHkLwhXA/y8jUHG6q7Yk.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1288,
#          'url': 'https://sun9-49.userapi.com/70_YTQVfPK2RjigVzmGMgOtyGC8-mqC6W-fPhQ/8TpDSQBEenI.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 304,
#          'url': 'https://sun9-76.userapi.com/BMrYr0YSqifVCm8ocrTuYF7L4I79m_j8YUrxkA/1y173406izY.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 406,
#          'url': 'https://sun9-9.userapi.com/ulIhfHaWpaA_Qriqy6_G95rcbyiN9nU9Pa3FUw/yY7zQRPVlDA.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 644,
#          'url': 'https://sun9-62.userapi.com/h1ZOJyRMeHPNAJIf5ZDTBNlhXFT7TBFnno97hA/hdziYOjg2QQ.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 163, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 40986}},
#    {'id': 13453,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1597834786,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ВОСХОЖДЕНИЕ НА ЗИМНИЙ ЭЛЬБРУС\nНачинаем набор участников! Распродажа на этой неделе! \n\nЗимнее восхождение отличается от летнего более суровыми погодными условиями. Но и оно под силу обычному человеку со средней физической формой, поскольку в программе нет переходов с полным рюкзаком, используется канатка и по желанию клиентов может быть использован ратрак. Вам потребуется максимально теплая одежда, которую, как и все снаряжение, вы сможете арендовать у нас в офисе. Спальник используем такой же, как летом, поскольку приют, в котором мы будем жить, отапливается. Численность группы меньше, чем летом. На одного инструктора приходится не более 4 клиентов. Группу сопровождают наши лучшие профессионалы - Сергей Тарасов и Алексей Сикилинда. Они обеспечат вашу полную безопасность во время восхождения. Ну и бонусом вам будет максимально прозрачный воздух на вершине, какой бывает только зимой.\n\nЭтой зимой, с 1 ноября 2020 по 21 марта 2021 у нас запланированы 11 зимних туров на Эльбрус. Один из них - новогодний! С восхождением на вершину в ночь с 31го на 1ое. Обычно зимние туры отличаются высокой стоимостью, но мы сделали их максимально доступными и в то же время комфортными. \n\nДо конца недели цена на зимние туры: 30 000 руб.\n\nРасписание туров, подробное описание и бронирование туров здесь: \nhttps://strahu-net.com/raspisanie/?year=2021',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://strahu-net.com/raspisanie/?year=2021',
#        'title': 'Старт продаж! Зимние туры на Эльбрус.',
#        'caption': 'strahu-net.com',
#        'description': 'Восхождения на Эльбрус с 4х сторон Света, 10 маршрутов от 1 до 14 дней, разной сложности, протяженности и уровня комфорта.',
#        'photo': {'album_id': -28,
#         'date': 1597834786,
#         'id': 457306627,
#         'owner_id': 2000020613,
#         'has_tags': False,
#         'sizes': [{'height': 89,
#           'url': 'https://sun9-5.userapi.com/FN8PGaPXfwH2OTgqcaR1OXbzuHJzuptvG9makA/QuKuiyF6QWs.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-38.userapi.com/bsOGNIkBeZBtJxkpS3gnpC0MAX0redbeZA65aA/VWcWP-U5_Bw.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-10.userapi.com/cbjKDDsDX7xBHk8ozEFI7FaF-p33KBpQ_QoAXQ/9EiDV5jcfMc.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-33.userapi.com/82W1xV6GbzAyrlBdTKqvz90YbDTb4ex0tc1kwg/UmWPbuBU90Y.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-67.userapi.com/tpz0xuTKHBgzhaaCd4v0lXV8WSjyOwveC0lMQA/NusTCr_3H5U.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 479,
#           'url': 'https://sun9-48.userapi.com/x8FGKscEkCw2CDLGn-xBAIjd8_HJWMb8m2FrTA/12-5nKCSRFs.jpg',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-66.userapi.com/fn2RpFRwjyYLhatMD88i12ZaBctFksaUiFdZ8Q/KmEfEXUuVNU.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 479,
#           'url': 'https://sun9-18.userapi.com/NaJ6XkEasby2k7GZNZmVIPLF8kOEV8Ane3mmQw/fMHyjm4gPH0.jpg',
#           'type': 'o',
#           'width': 1073}],
#         'text': ''}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 6, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 269, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 6, 'user_reposted': 0},
#     'views': {'count': 73377}},
#    {'id': 13444,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1597564179,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '60a1e9a096ec34e4f4',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 7,
#        'date': 1597564181,
#        'description': '',
#        'duration': 2181,
#        'photo_130': 'https://sun9-18.userapi.com/qx0UL2d7hvC56B8aOrpfvewXajWlTtsJ1i8p8w/4DwZ72JBzJc.jpg',
#        'photo_320': 'https://sun9-30.userapi.com/bU5WM_hdxVNqzirWtvQmgag1cNHxq0KllQJpfg/OFlVH1Y-n74.jpg',
#        'photo_800': 'https://sun9-5.userapi.com/Ds020oCu76xBp90U2_mlRm6m3erMhXY2Er9Clw/MxyG35tTQj8.jpg',
#        'photo_1280': 'https://sun9-27.userapi.com/-zQuW61rqGMoJu89RPbZyiqlHuu3jiuGOskS3A/6pIkoHI8ZfQ.jpg',
#        'first_frame_130': 'https://sun9-34.userapi.com/uPehd56KdrpTQ-KfDQQ7O0aEzPyq1R7edPvrGA/zK_fqf_HF5k.jpg',
#        'first_frame_160': 'https://sun9-39.userapi.com/bpN-ClcgvVmLtP0IAD3leg17htxQI-CvAoqMww/ijba9Ezs5lg.jpg',
#        'first_frame_320': 'https://sun9-69.userapi.com/_Aa3fz2sM71H7jgjlJem97q0iKyl2u_-ajZBpg/mTervflXBXU.jpg',
#        'first_frame_800': 'https://sun9-17.userapi.com/DuxUrynbPU7LV1eu2uksB_IQoTKlZfa5LGQhKg/SLddGEX0JoI.jpg',
#        'first_frame_1280': 'https://sun9-61.userapi.com/rrKT1UtbhcY5f4oThlqY3y4euLWr7TLslEahlA/rWgVwz_Hkgc.jpg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456239084,
#        'owner_id': -9690799,
#        'title': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#        'track_code': 'video_253a1efa9hF72nUQjjn0aqIChn4tEZxa6et-ZUnjNbI2JTQ9AU7NOgnScB2KOs1T_TazSB8ipWrR3w',
#        'views': 5639}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 7, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 15, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 6064}},
#    {'id': 13432,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1597214895,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': 'f4da023fc7d86ce5bb',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 3,
#        'date': 1597214897,
#        'description': '',
#        'duration': 664,
#        'photo_130': 'https://sun9-14.userapi.com/i5foKpTEFrPt8DubN-gRJVKqLvbVB-xr8CTXNA/ERHLLfHHcaM.jpg',
#        'photo_320': 'https://sun9-63.userapi.com/foaXw6kxya_8Q9vkYSWnWXVf67AhB52ZoEmYUw/GvVGkbuBzgE.jpg',
#        'photo_800': 'https://sun9-36.userapi.com/5iRpzQC6CdHzdMY6vEm4hQV51WFnUFLk_jFA8A/bhQL_6S9alk.jpg',
#        'photo_1280': 'https://sun9-33.userapi.com/DJp4RM9xIPyez5NW8LiaVYQ1GjoBqREVI4oXhw/pF6Colv_JDI.jpg',
#        'first_frame_130': 'https://sun9-26.userapi.com/rR1vveaSy76-L79V-q63mpqZSPijQjiLJXLYgw/l8qICJEBDH4.jpg',
#        'first_frame_160': 'https://sun9-41.userapi.com/c550vpyuSb4KCX8ThefG1te1-6jHfY00BDCHCw/DWkQ-WhBk5Y.jpg',
#        'first_frame_320': 'https://sun9-59.userapi.com/pb0v9fggfHgJ9AnIEBx3xs69b4KlA3QgJLQXag/yfMibh0pEKk.jpg',
#        'first_frame_800': 'https://sun9-70.userapi.com/9b0wX7Cu_0HvrWK3CpRNbrvyX2I3Syimdkb6Dw/115CFIw8hJs.jpg',
#        'first_frame_1280': 'https://sun9-45.userapi.com/lcgwfYIosnmVrA9DgqLLO2OLPlz3JOkzOL2jog/1485rOAFmSw.jpg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456239083,
#        'owner_id': -9690799,
#        'title': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#        'track_code': 'video_47fd9232mGhU06IU1SHZCDDDWMgxo5ituQTByHT1IkdR5bUKoNqjQybbpxnWJOAxb_dt_gOQoZ2BNw',
#        'views': 4521}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 3, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 22, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 6367}},
#    {'id': 13426,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1597000688,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ГОРЯЩЕЕ ПРЕДЛОЖЕНИЕ!\n\nМаршрут: Восхождение на Эльбрус с востока, самый красивый маршрут. Проходит по дикому ущелью, где нет никаких следов цивилизации. Необходимо иметь по меньшей мере среднюю физическую форму. Специальная техническая подготовка не требуется.\n\nИнструктор: Алексей Артюхин - Мастер Спорта, Чемпион СНГ по альпинизму и автор книги "Дорога к вершинам". (Каждый участник группы получит в подарок эту книгу с подписью автора.)\n\nДата начала: 23 августа 2020\n\nЦена со скидкой: 25 000 руб. \n\nРегистрация на тур здесь: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-po-dikomu-marshrutu-s-vostoka-s-artyuhinym/\n\nА все вопросы вы можете задать в комментах, в чате группы или по телефону 8 800 7777 044',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': 'cac090d2882cb965c3',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 0,
#        'date': 1596998572,
#        'description': '',
#        'duration': 44,
#        'photo_130': 'https://sun9-62.userapi.com/ziA10bLK1SDNa4awjmLdBcl40BJJkkJzt6NOow/NuqIFnhAKK0.jpg',
#        'photo_320': 'https://sun9-59.userapi.com/ETtydj-VyLaOB2PrBsuQ-TLmVdntsPI-AjEqCg/wUnPxhtoaoU.jpg',
#        'photo_800': 'https://sun9-45.userapi.com/AaIJomsBiB4kbmAr2Uj6NN-z52bSmUfbmJ2wBg/OJV0q3OCSiU.jpg',
#        'photo_1280': 'https://sun9-44.userapi.com/I-4NRuwIZKvUqGrqR_YDtPrfIBU2yUMurtwsLg/qscdAxjQUz0.jpg',
#        'first_frame_130': 'https://sun9-46.userapi.com/qb9U9k4GbPlk4C5akXJP329LrCQGVDn7CLM8OA/zRKtHonVpkY.jpg',
#        'first_frame_160': 'https://sun9-63.userapi.com/qYU4Izvj25sqvhU28MWF6q5tX2Q-gTi-xxWGUg/eMiT-SFiG1E.jpg',
#        'first_frame_320': 'https://sun9-54.userapi.com/ifEX9vKG__e9MVIeeQANtAEaq6z6W7wFzcOPPw/PITv24byktM.jpg',
#        'first_frame_800': 'https://sun9-40.userapi.com/qZHSY7hK_AtZhwij1eZfeieYJ3yPnq_WOLHSog/_hhnFlYaMdM.jpg',
#        'first_frame_1280': 'https://sun9-62.userapi.com/hHpn0U__Dun6d1gO8OaV9MUtUhujV-JXmqjSHA/nsrxZg_ZiH0.jpg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456239082,
#        'owner_id': -9690799,
#        'title': 'Untitled',
#        'track_code': 'video_eb37dd83jwbJK44J-aPQSa25lJEQvTs0fzatejEJmquKpUrAqV60LbsjiwT7oulw8o2hpyKOAgRHBA',
#        'views': 68937}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 12, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 300, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 7, 'user_reposted': 0},
#     'views': {'count': 63601}},
#    {'id': 13401,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1596525625,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Live: 4.08.2020 Инструктор, мастер спорта по альпинизму Гергель Алексей проводит брифинг перед походом на Казбек',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '41809e77fb19a9901b',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 16,
#        'date': 1596525626,
#        'description': '',
#        'duration': 1134,
#        'photo_130': 'https://sun9-63.userapi.com/tXPn47qVNIvvWSEEUeFWmIYboNyf39kugaeliQ/l-g2m3CCWCE.jpg',
#        'photo_320': 'https://sun9-22.userapi.com/aPSsiriJkVrmj0tqdEx54age2oT0JF5aWP2Daw/itwwwzAjqGs.jpg',
#        'photo_800': 'https://sun9-59.userapi.com/QY5TOUHv1xBsbmmQF1xPZgatoAgcUhTtWn2T6w/0nLbR-tibDk.jpg',
#        'photo_1280': 'https://sun9-46.userapi.com/FmMlapaw2G60AOkeVaDXZ4upYBFXjYBt-eqEUQ/hb80SQ0PYGY.jpg',
#        'first_frame_130': 'https://sun9-46.userapi.com/NCq1Q_6Y2uFZPFD-ypRn2RZoiweyXfOO5HpnLA/KayPpLHpRWA.jpg',
#        'first_frame_160': 'https://sun9-3.userapi.com/5nkjvRaAvo8tLkJTeFnwsZr7Sba75ANCQBdbIA/2QTszkcWQf8.jpg',
#        'first_frame_320': 'https://sun9-1.userapi.com/CylhdPUZv98sD4-Ct1GgbPheAuGVPjt6DqfLtA/Hkws-WD9Zu8.jpg',
#        'first_frame_800': 'https://sun9-51.userapi.com/4sM5diJ9kw__-UbjBTQ_BRQEriwbkyYa_HRulw/88easuikkFg.jpg',
#        'first_frame_1280': 'https://sun9-50.userapi.com/V_yoFC8l-N329i1f4EQuLF-TZPwD_JNe6nVoAw/Vn6kO_orh10.jpg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456239081,
#        'owner_id': -9690799,
#        'title': 'Live: Восхождение на Эльбрус | Elbrus Climbing',
#        'track_code': 'video_d419807bDpUsvUAM6-Q1VojGt0c2gZNHMoLbRfbA6raPX1aVNpI1vl61RQHr4gxv1_KCcQSyqncKsw',
#        'views': 14522}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 16, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 52, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 3, 'user_reposted': 0},
#     'views': {'count': 8571},
#     'edited': 1596530499},
#    {'id': 13389,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1595870407,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Начинаем набор группы в поход на Эльбрус с востока под руководством Алексея Артюхина, Мастера Спорта, Чемпиона России и автора книги "Дорога к вершинам". Каждый участник группы получит в подарок эту книгу с подписью автора.\n\nО маршруте: это самый наш красивый и самый сложный маршрут. Проходит по дикому ущелью, где нет никаких следов цивилизации. Необходимо иметь по меньшей мере среднюю физическую форму. Специальная техническая подготовка не требуется.\n\nДата начала: 23 августа 2020\n\nЦена со скидкой: 25 000 руб. (действительна до 31 июля включительно)\n\nРегистрация на тур здесь: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-po-dikomu-marshrutu-s-vostoka-s-artyuhinym/',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1595870406,
#        'id': 457242504,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '2af7b3e305a5704c59',
#        'post_id': 13389,
#        'sizes': [{'height': 130,
#          'url': 'https://sun9-41.userapi.com/ij_e6uAb6onRtL105CEH6pTsfomiAnV8xjRV_Q/7mWomrdgGrM.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 130,
#          'url': 'https://sun9-41.userapi.com/ij_e6uAb6onRtL105CEH6pTsfomiAnV8xjRV_Q/7mWomrdgGrM.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 200,
#          'url': 'https://sun9-48.userapi.com/oOCGkwMh4eLpv2UU9uet-JN1bEydMInZQnryaA/wqZOcI_zlXE.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 320,
#          'url': 'https://sun9-21.userapi.com/SVfFySKFZJMYHoe4sd9_0Q849VkuFTzLajm7QQ/v3VkfweVhqs.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 510,
#          'url': 'https://sun9-10.userapi.com/NfQ3n4Ky4vnEVF_Svt7hPtyx0PUd434B9KWI_A/xd27CpCOqb0.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 75,
#          'url': 'https://sun9-47.userapi.com/uDiH1pNRGlvPne7TDHDsUfvtin4DZam0NyPCcg/0n744smIVD8.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 604,
#          'url': 'https://sun9-11.userapi.com/7Ub1cqKp0n_A-6BCU1thC9DJhEWoD5EVzuC5JQ/nFW7Mofwz1E.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 807,
#          'url': 'https://sun9-42.userapi.com/C7xwqH5y2QhkSPt1WlRFBTkfBXVZj9QfpZuQyw/S2nacuImuBQ.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 1046,
#          'url': 'https://sun9-72.userapi.com/OZ0e33jvArWTZKoLXnaRhUVt4aG_zLGB2J7QiQ/Kj6Je1qgtOQ.jpg',
#          'type': 'z',
#          'width': 1046}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 5, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 56, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1, 'user_reposted': 0},
#     'views': {'count': 12636}},
#    {'id': 13379,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1595755712,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Еще вчера этим двум ребятам Сергей Тарасов проводил брифинг в нашем офисе в Пятигорске, а уже сегодня они на вершине Эльбруса. Восхождение с кислородом за один день. Как вам такой уикенд?\n\nВ этом году у нас планируется еще 2 плановые группы с кислородом. Но данный тур мы также проводим по индивидуальному запросу в любое удобное для вас время. \n\nЗдесь расписание предстоящих кислородных туров: https://strahu-net.com/raspisanie-turov-na-elbrus/?ROUTE=Climbing_for_1_day',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1595755712,
#        'id': 457242503,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '1d8881ba614832f60f',
#        'post_id': 13379,
#        'sizes': [{'height': 96,
#          'url': 'https://sun9-13.userapi.com/54hXXldYGGQP-WGonuOyGpxDPpr_DMZ5Ylctig/AhHLmZyfjIM.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 96,
#          'url': 'https://sun9-13.userapi.com/54hXXldYGGQP-WGonuOyGpxDPpr_DMZ5Ylctig/AhHLmZyfjIM.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 148,
#          'url': 'https://sun9-4.userapi.com/8KkqxhXBJpG449eUy5RXelonmeiCL4pNnag2Fg/nHKAqAzuAkw.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 236,
#          'url': 'https://sun9-46.userapi.com/BrEm7S6zaXGmHdqIXTMrg-wovk8sv2yTm9JFdA/HZDi-zBLeLs.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 376,
#          'url': 'https://sun9-21.userapi.com/0dSCfWL4iTyaWmTCuR7qxG16-cySX8TVTjF0Vg/oBwYbB0utuo.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 55,
#          'url': 'https://sun9-26.userapi.com/Z18T7uQm359vCMDLkWBrrV80vU91R8o8OWm4KA/-oUWzgnhfDQ.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 445,
#          'url': 'https://sun9-67.userapi.com/XQzBBOdltfBNmBqYRcwsAFVn1v0ziUKKhd3gbA/Tig-BGm99ec.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 595,
#          'url': 'https://sun9-53.userapi.com/L9xEO-3GBRSl24tPbI9zbD4aZh5EWa1d8lDORQ/GMgOpO7rfKU.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 885,
#          'url': 'https://sun9-9.userapi.com/g8XJIpn1sBwkCHYjXg_QC_kcoRLoqB4UrGYvZA/Yz1CCO5Njso.jpg',
#          'type': 'z',
#          'width': 1200}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 10, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 90, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 0, 'user_reposted': 0},
#     'views': {'count': 14309}},
#    {'id': 13374,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1595698325,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'РАБОТА ГОРНЫМ ГИДОМ НА ЭЛЬБРУСЕ\n\nПриглашаем к нам в компанию горных гидов для работы первыми и вторыми гидами с нашими группами на Эльбрусе.\n\nЕсли вас интересует эта вакансия, заполните пожалуйста, анкету на этой странице: https://strahu-net.com/careers/',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://strahu-net.com/careers/',
#        'title': 'Вакансии',
#        'caption': 'strahu-net.com',
#        'description': 'Вакансии',
#        'photo': {'album_id': -28,
#         'date': 1595698325,
#         'id': 457301691,
#         'owner_id': 2000008279,
#         'has_tags': False,
#         'sizes': [{'height': 89,
#           'url': 'https://sun9-22.userapi.com/VuPxE1j08jYshVcH9B43nco75HXh6vGYLjjfPg/mb8cGBH9WhM.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-50.userapi.com/A77wD78bcGDH9hPx_wweb-F0y2mu-Q5jS4J5Xg/iLNdJo93l_k.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-45.userapi.com/trdr6n6bMVDdnVJ489jq8WzFXhLo_KZPgYLMRg/0-JIEHSMAwU.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-34.userapi.com/QeGD9IIZ8ZRxH4qYa7qH1vRWHNQpWdJq5G7XbQ/rGwhIsD9ha4.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-49.userapi.com/F5iLXyCD2QbggQcx24zu8AhPxo5IkDtlxcCxNQ/yFbdg2d4H_I.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 480,
#           'url': 'https://sun9-8.userapi.com/Pv9m9GRyQHdxr-iAoI4g9jJDH1VtJQwXSf3C0g/tFJD9kxsZh8.jpg',
#           'type': 'k',
#           'width': 1073},
#          {'height': 240,
#           'url': 'https://sun9-36.userapi.com/JyICkaJ-DT50TenPjAzSv6N8rg0-B9k2xF386A/-7XiW4RWYPo.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 454,
#           'url': 'https://sun9-45.userapi.com/gJD8CYr6LmYd93oJ90_yUncqz1t54EG3lkC_lw/5fxf37Lq8U8.jpg',
#           'type': 'o',
#           'width': 1015}],
#         'text': ''}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 49, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 4, 'user_reposted': 0},
#     'views': {'count': 17435}},
#    {'id': 13365,
#     'from_id': -9690799,
#     'owner_id': -9690799,
#     'date': 1595515264,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'СПЕЦПРЕДЛОЖЕНИЕ: Горящие туры на Эльбрус в самое ближайшее время.\n\n29 июля - восхождение на Эльбрус с юга - 10 000 руб \nРегистрация: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-s-yuga-23/\n\n1 августа - восхождение на Эльбрус с юга с Чемпионом России по альпинизму Алексеем Сикилинда - 12 000 руб \nРегистрация: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-s-yuga-04983/\n\n3 августа - восхождение на Эльбрус с востока - 24 000 руб \nРегистрация: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-po-dikomu-marshrutu-s-vostoka-198/\n\n12 августа - комфортное восхождение на Эльбрус (канатка, ратрак, отель...) с чемпионом России по альпинизму Алексеем Артюхиным (каждому участнику в подарок книга Алексея "Дорога к вершинам" с подписью автора) - 25 000 руб.\nРегистрация: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/komfortnoe-voskhozhdenie-na-elbrus-s-yuga-0987/\n\n13 августа - восхождение на Эльбрус с юга с Чемпионом России по альпинизму Алексеем Сикилинда - 12 000 руб \nРегистрация: https://strahu-net.com/raspisanie-turov-na-elbrus/tur/elbrus-s-yuga345/\n\nНа фото: Привал на маршруте восхождения на Эльбрус с юга.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1595515264,
#        'id': 457242502,
#        'owner_id': -9690799,
#        'has_tags': False,
#        'access_key': '61037dd43bd38d4835',
#        'post_id': 13365,
#        'sizes': [{'height': 97,
#          'url': 'https://sun9-73.userapi.com/uipK91qy_WjoS2XndlFIWsnlX-vVLe3Zrvdzaw/Zcl92N_m_fI.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 98,
#          'url': 'https://sun9-11.userapi.com/TxdQbMairR5iM4SPQ7IDSGUz0YQ1cVFf1qChhw/yBC63QayoCM.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 150,
#          'url': 'https://sun9-34.userapi.com/w14Sbzvse9v6ZuO8dh-USqztEZwVhPHXoe7oWw/72WUF5HBraQ.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 240,
#          'url': 'https://sun9-35.userapi.com/I43DArF2kurq0eLDSO7ZyIr1uuvfTVzaOi6wLA/ZMimRq_A6bM.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 383,
#          'url': 'https://sun9-13.userapi.com/AzbqxpMELkuEA_Lb4_6UAUt1T-lNWka7qsxZLQ/GM275EzckYg.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 56,
#          'url': 'https://sun9-62.userapi.com/dONkLATOg5m0AN8nopQ0XPZUKKuTro4YMRK13A/qxBDiNvkE2E.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1920,
#          'url': 'https://sun9-54.userapi.com/jV02_hRtnVDMoiLV_e5ajUmhkEDZOCITOp-vxA/Ly32Pv4Uut4.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 453,
#          'url': 'https://sun9-11.userapi.com/46T1YJEOGCcMfO0RrSfsK_erejSerC3rrz_Lcw/dHPreIKrdKY.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 605,
#          'url': 'https://sun9-8.userapi.com/twD0_akvNz4ssyU06JWax7lBsXTcTctB3OkHSg/LCqWyvlbqY0.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 960,
#          'url': 'https://sun9-68.userapi.com/vJwJFdnZ-Na4-44Gc1t5WfmBJTjp86a5lHo3Ig/1Z6GaVvCjPw.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 9, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 804, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 10, 'user_reposted': 0},
#     'views': {'count': 95351}}]}}

# %% [markdown]
# Видим, что сначала идёт общее количество постов, а по ключу 'items'  —  сами посты. Посмотрим на отдельный пост:

# %%
response.json()['response']['items'][0]  
# {'id': 13401,  
#  'from_id': -9690799,  
#  'owner_id': -9690799,  
#  'date': 1596525625,  
#  'marked_as_ads': 0,  
#  'post_type': 'post',  
#  'text': 'Live: 4.08.2020 Инструктор, мастер спорта по альпинизму Гергель Алексей проводит брифинг перед походом на Казбек',  
# ...  
#    'title': 'Live: Восхождение на Эльбрус | Elbrus Climbing',  
#    'track_code': 'video_a01b60fecgAaGKK4Ixj13XSddJY5HBUZCTQcBUaoa1vY2ZWYaHRJK2gQp7UjHszkK6lBoAsvLCkxBQ',  
#    'views': 8848}}],  
#  'post_source': {'type': 'vk'},  
#  'comments': {'count': 16, 'can_post': 1, 'groups_can_post': True},  
#  'likes': {'count': 41, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},  
#  'reposts': {'count': 3, 'user_reposted': 0},  
#  'views': {'count': 5837},
#  'edited': 1596530499}
# Out:
# {'id': 13482,
#  'from_id': -9690799,
#  'owner_id': -9690799,
#  'date': 1598188550,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'Последние 10 туров на Эльбрус в этом сезоне, которые еще доступны для бронирования. \nРасписание 2020, описание маршрутов и бронирование здесь: https://strahu-net.com/raspisanie-turov-na-elbrus/?year=2020',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1598188543,
#     'id': 457242581,
#     'owner_id': -9690799,
#     'has_tags': False,
#     'access_key': '04ffc873146b0f0bf5',
#     'post_id': 13482,
#     'sizes': [{'height': 65,
#       'url': 'https://sun9-56.userapi.com/2jgpYP7K7Bn0KUQRBrBs5sTiNVYS8oNyDJwBwQ/-NQdNzlSXTI.jpg',
#       'type': 'm',
#       'width': 130},
#      {'height': 87,
#       'url': 'https://sun9-2.userapi.com/IPbtbVfkd3KdYy41z6eR2CJJqY79FJgdn8bATw/ghCgd2y6Ymk.jpg',
#       'type': 'o',
#       'width': 130},
#      {'height': 133,
#       'url': 'https://sun9-71.userapi.com/GALNTGZAbfiizVPaGERbJmOrUw5c84TTpHAS0g/0b0kiSnKV2I.jpg',
#       'type': 'p',
#       'width': 200},
#      {'height': 213,
#       'url': 'https://sun9-68.userapi.com/wyeS3dzKrzeDT4ZvyeBSymGhEslQrH17svWIKA/dXkucKOkUVo.jpg',
#       'type': 'q',
#       'width': 320},
#      {'height': 340,
#       'url': 'https://sun9-1.userapi.com/E0siT_rAEA8jm9VkO-wRsh0qzFIUV_dtCxFi0g/1yVVYVc14xs.jpg',
#       'type': 'r',
#       'width': 510},
#      {'height': 37,
#       'url': 'https://sun9-65.userapi.com/r_nNdYwZAo3FT7LzhFUz1pxD8i67vWUHkLwhXA/y8jUHG6q7Yk.jpg',
#       'type': 's',
#       'width': 75},
#      {'height': 1288,
#       'url': 'https://sun9-49.userapi.com/70_YTQVfPK2RjigVzmGMgOtyGC8-mqC6W-fPhQ/8TpDSQBEenI.jpg',
#       'type': 'w',
#       'width': 2560},
#      {'height': 304,
#       'url': 'https://sun9-76.userapi.com/BMrYr0YSqifVCm8ocrTuYF7L4I79m_j8YUrxkA/1y173406izY.jpg',
#       'type': 'x',
#       'width': 604},
#      {'height': 406,
#       'url': 'https://sun9-9.userapi.com/ulIhfHaWpaA_Qriqy6_G95rcbyiN9nU9Pa3FUw/yY7zQRPVlDA.jpg',
#       'type': 'y',
#       'width': 807},
#      {'height': 644,
#       'url': 'https://sun9-62.userapi.com/h1ZOJyRMeHPNAJIf5ZDTBNlhXFT7TBFnno97hA/hdziYOjg2QQ.jpg',
#       'type': 'z',
#       'width': 1280}],
#     'text': '',
#     'user_id': 100}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 163, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 1, 'user_reposted': 0},
#  'views': {'count': 40986}}

# %% [markdown]
# Нужная нам статистика находится в полях 'comments', 'likes' и 'reposts'. Соберем итоговую статистику для каждого поста в словарь stats. В качестве ключа будем использовать начало статьи, в качестве значения — список с тремя интересующими нас метриками и временем публикации: [комментарии, лайки, репосты, дата публикации]

# %%
stats = {}  
              
for record in response.json()['response']['items'][:]:  
    title = record['text'][:30]  
    if title:  
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]  
pprint(stats)  
  
# => {'7 ГОРЯЩИХ ТУРОВ НА ЭЛЬБРУС ЭТО': [21, 101, 3, 1595188793],  
#     'Live: 4.08.2020 Инструктор, ма': [16, 41, 3, 1596525625],  
#     'Еще вчера этим двум ребятам Се': [10, 82, 0, 1595755712],  
#     'Начинаем набор группы в поход ': [4, 48, 1, 1595870407],  
#     'Осталось 10 туров на Эльбрус, ': [28, 399, 6, 1594321990],  
#     'Приглашаем к сотрудничеству!\n\n': [2, 54, 1, 1594208684],  
#     'Прямой эфир 21.07.2020. Инстру': [34, 93, 5, 1595317547],  
#     'РАБОТА ГОРНЫМ ГИДОМ НА ЭЛЬБРУС': [1, 44, 2, 1595698325],  
#     'СПЕЦПРЕДЛОЖЕНИЕ: Горящие туры ': [9, 802, 10, 1595515264]}
# Out:
# {'Live: 4.08.2020 Инструктор, ма': [16, 52, 3, 1596525625],
#  'Live: Восхождение на Эльбрус |': [3, 22, 0, 1597214895],
#  'ВОСХОЖДЕНИЕ НА ЗИМНИЙ ЭЛЬБРУС\n': [6, 269, 6, 1597834786],
#  'ГОРЯЩЕЕ ПРЕДЛОЖЕНИЕ!\n\nМаршрут:': [12, 300, 7, 1597000688],
#  'Еще вчера этим двум ребятам Се': [10, 90, 0, 1595755712],
#  'Начинаем набор группы в поход ': [5, 56, 1, 1595870407],
#  'Последние 10 туров на Эльбрус ': [0, 163, 1, 1598188550],
#  'РАБОТА ГОРНЫМ ГИДОМ НА ЭЛЬБРУС': [1, 49, 4, 1595698325],
#  'СПЕЦПРЕДЛОЖЕНИЕ: Горящие туры ': [9, 804, 10, 1595515264]}

# %% [markdown]
# #### Задание 1 - SMM index
#
# Напишите функцию get_smm_index(group_name, token), которая по имени группы и авторизационному токену API возвращает smm_index группы - сумму лайков, комментариев и репостов для последних 10 постов, поделённую на количество участников в группе.

# %%
def get_smm_index(group_name, token):
    
    # Количество пользователей в группе    
    url = 'https://api.vk.com/method/groups.getMembers'  
    params = {  
        'group_id': group_name,  
        'v': 5.95,  
        'access_token': token  
    }  
    
    response = requests.get(url, params = params)  
    
    user_count = response.json()['response']['count']

    
    # Вытягиваем последние новости
    url = 'https://api.vk.com/method/wall.get'  
    params = {  
    'domain': group_name,  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': token,  
    'v': 5.95  
    } 
    
    response = requests.get(url, params = params)    
    
    stats = 0  
              
    for record in response.json()['response']['items'][:]:  
        stats += (record['comments']['count'] + record['likes']['count'] + record['reposts']['count'])
    
    return user_count, stats/ user_count
    
    


get_smm_index('mountelbrus', token)
# Out:
# (66145, 0.02905737395116789)

# %%
import requests 
def get_smm_index(group_name, token):
  # количество участников группы
    url_m = 'https://api.vk.com/method/groups.getMembers'  
    params = {'group_id': group_name, 'v': 5.95, 'access_token': token}  
    response_m = requests.get(url_m, params = params)  
    data_m = response_m.json()  
    members = data_m['response']['count']
  # количество лайков, комментарией, репостов в 10 сообщениях
    comments = []
    likes = []
    reposts = []
    url_s = 'https://api.vk.com/method/wall.get'  
    params = { 'domain': group_name, 'filter': 'owner','count': 10, 'offset': 0,'access_token': token,'v': 5.95}  
    response_s = requests.get(url_s, params = params)  
    data_s = response_s.json()
    data=data_s['response']
    for i in data['items']:
        likes.append(i['likes']['count'])
        reposts.append(i['reposts']['count'])
        comments.append(i['comments']['count'])
  # smm_index
    smm_index = (sum(comments) + sum(likes) + sum(reposts))/members     
    return smm_index

get_smm_index('mountelbrus', token)
# Out:
# 0.02905737395116789

# %% [markdown]
# #### Возможности API

# %% [markdown]
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: по сути, всё, что можно делать руками через браузер, доступно и в API. Обратим внимание: если вы размещаете рекламу в Вконтакте, то можно выгружать всю статистику через ads API.
#
# Полный список методов можно посмотреть в документации - https://vk.com/dev/methods
